# %%
from pathlib import Path
import pickle
import numpy as np
import pretty_midi

# %%
artists_songs_paths = {
    'Bach': ['data/orchestra/bach'],
    'Mozart': ['data/orchestra/mozart'],
    'Schumann x Chopin': ['data/orchestra/schumann', 'data/orchestra/chopin'],
    'Debussy x Albeniz': ['data/orchestra/debussy', 'data/orchestra/albeniz'],
    'All': ['data/orchestra']
}

artists_notes_paths = {
    'Bach': 'data/notes_files/bach_notes',
    'Mozart': 'data/notes_files/mozart_notes',
    'Schumann x Chopin': 'data/notes_files/schumann_chopin_notes',
    'Debussy x Albeniz': 'data/notes_files/debussy_albeniz_notes',
    'All': 'data/notes_files/all_notes'
}

# %%
artist_notes = {}

# %%
for artist, paths in artists_songs_paths.items():
    
    training_notes = []
    
    # if artists_notes_paths[artist] file already exists, skip this artist
    if Path(artists_notes_paths[artist]).exists():
        with open(artists_notes_paths[artist], 'rb') as filepath:
            training_notes = pickle.load(filepath)
        
        artist_notes[artist] = training_notes
        
        continue

    for path in paths:
        for count, midi_file in enumerate(Path(path).rglob('*.mid')):
                print(f"Parsing {midi_file}")
                notes = []
                durations = []

                try:
                    #parsing MIDI files one by one
                    midi_data = pretty_midi.PrettyMIDI(str(midi_file))
                except:
                    print("Error parsing file: {}".format(midi_file))
                    continue

                #depending on the element found in the instrument. Like we would have 'rest' for drums,
                #chords for guitar
                instrument = midi_data.instruments[0] if len(midi_data.instruments) > 0 else None
                
                if instrument is None:
                    continue
                
                sorted_notes = sorted(instrument.notes, key=lambda x: x.start)
                
                chord = [instrument.notes[0]]
                chord_end = instrument.notes[0].end
                first = True
                for note in sorted_notes:
                    if first:
                        first = False
                        continue
                    
                    if note.start > chord_end:
                        notes.append(chord)
                        chord = []
                        chord_end = note.end
                        chord.append(note)
                    else:
                        chord.append(note)
                        chord_end = note.end if note.end > chord_end else chord_end
                
                #notes and duration hold seuence for one music piece. 
                training_notes.append(notes)
    
    artist_notes[artist] = training_notes

    with open(artists_notes_paths[artist], 'wb') as filepath:
        pickle.dump(training_notes, filepath)
# Out:
# Parsing data\orchestra\bach\bach_846.mid
# Parsing data\orchestra\bach\bach_847.mid
# Parsing data\orchestra\bach\bach_850.mid
# Parsing data\orchestra\mozart\mz_311_1.mid
# Parsing data\orchestra\mozart\mz_311_2.mid
# Parsing data\orchestra\mozart\mz_311_3.mid
# Parsing data\orchestra\mozart\mz_330_1.mid
# Parsing data\orchestra\mozart\mz_330_2.mid
# Parsing data\orchestra\mozart\mz_330_3.mid
# Parsing data\orchestra\mozart\mz_331_1.mid
# Parsing data\orchestra\mozart\mz_331_2.mid
# Parsing data\orchestra\mozart\mz_331_3.mid
# Parsing data\orchestra\mozart\mz_332_1.mid
# Parsing data\orchestra\mozart\mz_332_2.mid
# Parsing data\orchestra\mozart\mz_332_3.mid
# Parsing data\orchestra\mozart\mz_333_1.mid
# Parsing data\orchestra\mozart\mz_333_2.mid
# Parsing data\orchestra\mozart\mz_333_3.mid
# Parsing data\orchestra\mozart\mz_545_1.mid
# Parsing data\orchestra\mozart\mz_545_2.mid
# Parsing data\orchestra\mozart\mz_545_3.mid
# Parsing data\orchestra\mozart\mz_570_1.mid
# Parsing data\orchestra\mozart\mz_570_2.mid
# Parsing data\orchestra\mozart\mz_570_3.mid
# Parsing data\orchestra\schumann\schum_abegg.mid
# Parsing data\orchestra\schumann\scn15_1.mid
# Parsing data\orchestra\schumann\scn15_10.mid
# Parsing data\orchestra\schumann\scn15_11.mid
# Parsing data\orchestra\schumann\scn15_12.mid
# Parsing data\orchestra\schumann\scn15_13.mid
# Parsing data\orchestra\schumann\scn15_2.mid
# Parsing data\orchestra\schumann\scn15_3.mid
# Parsing data\orchestra\schumann\scn15_4.mid
# Parsing data\orchestra\schumann\scn15_5.mid
# Parsing data\orchestra\schumann\scn15_6.mid
# Parsing data\orchestra\schumann\scn15_7.mid
# Parsing data\orchestra\schumann\scn15_8.mid
# Parsing data\orchestra\schumann\scn15_9.mid
# Parsing data\orchestra\schumann\scn16_1.mid
# Parsing data\orchestra\schumann\scn16_2.mid
# Parsing data\orchestra\schumann\scn16_3.mid
# Parsing data\orchestra\schumann\scn16_4.mid
# Parsing data\orchestra\schumann\scn16_5.mid
# Parsing data\orchestra\schumann\scn16_6.mid
# Parsing data\orchestra\schumann\scn16_7.mid
# Parsing data\orchestra\schumann\scn16_8.mid
# Parsing data\orchestra\schumann\scn68_10.mid
# Parsing data\orchestra\schumann\scn68_12.mid
# Parsing data\orchestra\chopin\chpn-p1.mid
# Parsing data\orchestra\chopin\chpn-p10.mid
# Parsing data\orchestra\chopin\chpn-p11.mid
# Parsing data\orchestra\chopin\chpn-p12.mid
# Parsing data\orchestra\chopin\chpn-p13.mid
# Parsing data\orchestra\chopin\chpn-p14.mid
# Parsing data\orchestra\chopin\chpn-p15.mid
# Parsing data\orchestra\chopin\chpn-p16.mid
# Parsing data\orchestra\chopin\chpn-p17.mid
# Parsing data\orchestra\chopin\chpn-p18.mid
# Parsing data\orchestra\chopin\chpn-p19.mid
# Parsing data\orchestra\chopin\chpn-p2.mid
# Parsing data\orchestra\chopin\chpn-p20.mid
# Parsing data\orchestra\chopin\chpn-p21.mid
# Parsing data\orchestra\chopin\chpn-p22.mid
# Parsing data\orchestra\chopin\chpn-p23.mid
# Parsing data\orchestra\chopin\chpn-p24.mid
# Parsing data\orchestra\chopin\chpn-p3.mid
# Parsing data\orchestra\chopin\chpn-p4.mid
# Parsing data\orchestra\chopin\chpn-p5.mid
# Parsing data\orchestra\chopin\chpn-p6.mid
# Parsing data\orchestra\chopin\chpn-p7.mid
# Parsing data\orchestra\chopin\chpn-p8.mid
# Parsing data\orchestra\chopin\chpn-p9.mid
# Parsing data\orchestra\chopin\chpn_op10_e01.mid
# Parsing data\orchestra\chopin\chpn_op10_e05.mid
# Parsing data\orchestra\chopin\chpn_op10_e12.mid
# Parsing data\orchestra\chopin\chpn_op23.mid
# Parsing data\orchestra\chopin\chpn_op25_e1.mid
# Parsing data\orchestra\chopin\chpn_op25_e11.mid
# Parsing data\orchestra\chopin\chpn_op25_e12.mid
# Parsing data\orchestra\chopin\chpn_op25_e2.mid
# Parsing data\orchestra\chopin\chpn_op25_e3.mid
# Parsing data\orchestra\chopin\chpn_op25_e4.mid
# Parsing data\orchestra\chopin\chpn_op27_1.mid
# Parsing data\orchestra\chopin\chpn_op27_2.mid
# Parsing data\orchestra\chopin\chpn_op33_2.mid
# Parsing data\orchestra\chopin\chpn_op33_4.mid
# Parsing data\orchestra\chopin\chpn_op35_1.mid
# Parsing data\orchestra\chopin\chpn_op35_2.mid
# Parsing data\orchestra\chopin\chpn_op35_3.mid
# Parsing data\orchestra\chopin\chpn_op35_4.mid
# Parsing data\orchestra\chopin\chpn_op53.mid
# Parsing data\orchestra\chopin\chpn_op66.mid
# Parsing data\orchestra\chopin\chpn_op7_1.mid
# Parsing data\orchestra\chopin\chpn_op7_2.mid
# Parsing data\orchestra\chopin\chp_op18.mid
# Parsing data\orchestra\chopin\chp_op31.mid
# Parsing data\orchestra\debussy\debussy_cc_1.mid
# Parsing data\orchestra\debussy\debussy_cc_2.mid
# Parsing data\orchestra\debussy\debussy_cc_3.mid
# Parsing data\orchestra\debussy\debussy_cc_4.mid
# Parsing data\orchestra\debussy\debussy_cc_6.mid
# Parsing data\orchestra\debussy\DEB_CLAI.MID
# Parsing data\orchestra\debussy\deb_menu.mid
# Parsing data\orchestra\debussy\DEB_PASS.MID
# Parsing data\orchestra\debussy\deb_prel.mid
# Parsing data\orchestra\albeniz\alb_esp1.mid
# Parsing data\orchestra\albeniz\alb_esp2.mid
# Parsing data\orchestra\albeniz\alb_esp3.mid
# Parsing data\orchestra\albeniz\alb_esp4.mid
# Parsing data\orchestra\albeniz\alb_esp5.mid
# Parsing data\orchestra\albeniz\alb_esp6.mid
# Parsing data\orchestra\albeniz\alb_se1.mid
# Parsing data\orchestra\albeniz\alb_se2.mid
# Parsing data\orchestra\albeniz\alb_se3.mid
# Parsing data\orchestra\albeniz\alb_se4.mid
# Parsing data\orchestra\albeniz\alb_se5.mid
# Parsing data\orchestra\albeniz\alb_se6.mid
# Parsing data\orchestra\albeniz\alb_se7.mid
# Parsing data\orchestra\albeniz\alb_se8.mid
# Parsing data\orchestra\albeniz\alb_esp1.mid
# Parsing data\orchestra\albeniz\alb_esp2.mid
# Parsing data\orchestra\albeniz\alb_esp3.mid
# Parsing data\orchestra\albeniz\alb_esp4.mid
# Parsing data\orchestra\albeniz\alb_esp5.mid
# Parsing data\orchestra\albeniz\alb_esp6.mid
# Parsing data\orchestra\albeniz\alb_se1.mid
# Parsing data\orchestra\albeniz\alb_se2.mid
# Parsing data\orchestra\albeniz\alb_se3.mid
# Parsing data\orchestra\albeniz\alb_se4.mid
# Parsing data\orchestra\albeniz\alb_se5.mid
# Parsing data\orchestra\albeniz\alb_se6.mid
# Parsing data\orchestra\albeniz\alb_se7.mid
# Parsing data\orchestra\albeniz\alb_se8.mid
# Parsing data\orchestra\bach\bach_846.mid
# Parsing data\orchestra\bach\bach_847.mid
# Parsing data\orchestra\bach\bach_850.mid
# Parsing data\orchestra\balakir\islamei.mid
# Parsing data\orchestra\beeth\appass_1.mid
# Parsing data\orchestra\beeth\appass_2.mid
# Parsing data\orchestra\beeth\appass_3.mid
# Parsing data\orchestra\beeth\beethoven_hammerklavier_1.mid
# Parsing data\orchestra\beeth\beethoven_hammerklavier_2.mid
# Parsing data\orchestra\beeth\beethoven_hammerklavier_3.mid
# Parsing data\orchestra\beeth\beethoven_hammerklavier_4.mid
# Parsing data\orchestra\beeth\beethoven_les_adieux_1.mid
# Parsing data\orchestra\beeth\beethoven_les_adieux_2.mid
# Parsing data\orchestra\beeth\beethoven_les_adieux_3.mid
# Parsing data\orchestra\beeth\beethoven_opus10_1.mid
# Parsing data\orchestra\beeth\beethoven_opus10_2.mid
# Parsing data\orchestra\beeth\beethoven_opus10_3.mid
# Parsing data\orchestra\beeth\beethoven_opus22_1.mid
# Parsing data\orchestra\beeth\beethoven_opus22_2.mid
# Parsing data\orchestra\beeth\beethoven_opus22_3.mid
# Parsing data\orchestra\beeth\beethoven_opus22_4.mid
# Parsing data\orchestra\beeth\beethoven_opus90_1.mid
# Parsing data\orchestra\beeth\beethoven_opus90_2.mid
# Parsing data\orchestra\beeth\elise.mid
# Parsing data\orchestra\beeth\mond_1.mid
# Parsing data\orchestra\beeth\mond_2.mid
# Parsing data\orchestra\beeth\mond_3.mid
# Parsing data\orchestra\beeth\pathetique_1.mid
# Parsing data\orchestra\beeth\pathetique_2.mid
# Parsing data\orchestra\beeth\pathetique_3.mid
# Parsing data\orchestra\beeth\waldstein_1.mid
# Parsing data\orchestra\beeth\waldstein_2.mid
# Parsing data\orchestra\beeth\waldstein_3.mid
# Parsing data\orchestra\borodin\bor_ps1.mid
# Parsing data\orchestra\borodin\bor_ps2.mid
# Parsing data\orchestra\borodin\bor_ps3.mid
# Parsing data\orchestra\borodin\bor_ps4.mid
# Parsing data\orchestra\borodin\bor_ps5.mid
# Parsing data\orchestra\borodin\bor_ps6.mid
# Parsing data\orchestra\borodin\bor_ps7.mid
# Parsing data\orchestra\brahms\brahms_opus117_1.mid
# Parsing data\orchestra\brahms\brahms_opus117_2.mid
# Parsing data\orchestra\brahms\brahms_opus1_1.mid
# Parsing data\orchestra\brahms\brahms_opus1_2.mid
# Parsing data\orchestra\brahms\brahms_opus1_3.mid
# Parsing data\orchestra\brahms\brahms_opus1_4.mid
# Parsing data\orchestra\brahms\br_im2.mid
# Parsing data\orchestra\brahms\br_im5.mid
# Parsing data\orchestra\brahms\BR_IM6.MID
# Parsing data\orchestra\brahms\br_rhap.mid
# Parsing data\orchestra\burgm\burg_agitato.mid
# Parsing data\orchestra\burgm\burg_erwachen.mid
# Parsing data\orchestra\burgm\burg_geschwindigkeit.mid
# Parsing data\orchestra\burgm\burg_gewitter.mid
# Parsing data\orchestra\burgm\burg_perlen.mid
# Parsing data\orchestra\burgm\burg_quelle.mid
# Parsing data\orchestra\burgm\burg_spinnerlied.mid
# Parsing data\orchestra\burgm\burg_sylphen.mid
# Parsing data\orchestra\burgm\burg_trennung.mid
# Parsing data\orchestra\chopin\chpn-p1.mid
# Parsing data\orchestra\chopin\chpn-p10.mid
# Parsing data\orchestra\chopin\chpn-p11.mid
# Parsing data\orchestra\chopin\chpn-p12.mid
# Parsing data\orchestra\chopin\chpn-p13.mid
# Parsing data\orchestra\chopin\chpn-p14.mid
# Parsing data\orchestra\chopin\chpn-p15.mid
# Parsing data\orchestra\chopin\chpn-p16.mid
# Parsing data\orchestra\chopin\chpn-p17.mid
# Parsing data\orchestra\chopin\chpn-p18.mid
# Parsing data\orchestra\chopin\chpn-p19.mid
# Parsing data\orchestra\chopin\chpn-p2.mid
# Parsing data\orchestra\chopin\chpn-p20.mid
# Parsing data\orchestra\chopin\chpn-p21.mid
# Parsing data\orchestra\chopin\chpn-p22.mid
# Parsing data\orchestra\chopin\chpn-p23.mid
# Parsing data\orchestra\chopin\chpn-p24.mid
# Parsing data\orchestra\chopin\chpn-p3.mid
# Parsing data\orchestra\chopin\chpn-p4.mid
# Parsing data\orchestra\chopin\chpn-p5.mid
# Parsing data\orchestra\chopin\chpn-p6.mid
# Parsing data\orchestra\chopin\chpn-p7.mid
# Parsing data\orchestra\chopin\chpn-p8.mid
# Parsing data\orchestra\chopin\chpn-p9.mid
# Parsing data\orchestra\chopin\chpn_op10_e01.mid
# Parsing data\orchestra\chopin\chpn_op10_e05.mid
# Parsing data\orchestra\chopin\chpn_op10_e12.mid
# Parsing data\orchestra\chopin\chpn_op23.mid
# Parsing data\orchestra\chopin\chpn_op25_e1.mid
# Parsing data\orchestra\chopin\chpn_op25_e11.mid
# Parsing data\orchestra\chopin\chpn_op25_e12.mid
# Parsing data\orchestra\chopin\chpn_op25_e2.mid
# Parsing data\orchestra\chopin\chpn_op25_e3.mid
# Parsing data\orchestra\chopin\chpn_op25_e4.mid
# Parsing data\orchestra\chopin\chpn_op27_1.mid
# Parsing data\orchestra\chopin\chpn_op27_2.mid
# Parsing data\orchestra\chopin\chpn_op33_2.mid
# Parsing data\orchestra\chopin\chpn_op33_4.mid
# Parsing data\orchestra\chopin\chpn_op35_1.mid
# Parsing data\orchestra\chopin\chpn_op35_2.mid
# Parsing data\orchestra\chopin\chpn_op35_3.mid
# Parsing data\orchestra\chopin\chpn_op35_4.mid
# Parsing data\orchestra\chopin\chpn_op53.mid
# Parsing data\orchestra\chopin\chpn_op66.mid
# Parsing data\orchestra\chopin\chpn_op7_1.mid
# Parsing data\orchestra\chopin\chpn_op7_2.mid
# Parsing data\orchestra\chopin\chp_op18.mid
# Parsing data\orchestra\chopin\chp_op31.mid
# Parsing data\orchestra\debussy\debussy_cc_1.mid
# Parsing data\orchestra\debussy\debussy_cc_2.mid
# Parsing data\orchestra\debussy\debussy_cc_3.mid
# Parsing data\orchestra\debussy\debussy_cc_4.mid
# Parsing data\orchestra\debussy\debussy_cc_6.mid
# Parsing data\orchestra\debussy\DEB_CLAI.MID
# Parsing data\orchestra\debussy\deb_menu.mid
# Parsing data\orchestra\debussy\DEB_PASS.MID
# Parsing data\orchestra\debussy\deb_prel.mid
# Parsing data\orchestra\granados\gra_esp_2.mid
# Parsing data\orchestra\granados\gra_esp_3.mid
# Parsing data\orchestra\granados\gra_esp_4.mid
# Parsing data\orchestra\grieg\grieg_album.mid
# Parsing data\orchestra\grieg\grieg_berceuse.mid
# Parsing data\orchestra\grieg\grieg_brooklet.mid
# Parsing data\orchestra\grieg\grieg_butterfly.mid
# Parsing data\orchestra\grieg\grieg_elfentanz.mid
# Parsing data\orchestra\grieg\grieg_halling.mid
# Parsing data\orchestra\grieg\grieg_kobold.mid
# Parsing data\orchestra\grieg\grieg_march.mid
# Parsing data\orchestra\grieg\grieg_once_upon_a_time.mid
# Parsing data\orchestra\grieg\grieg_spring.mid
# Parsing data\orchestra\grieg\grieg_voeglein.mid
# Parsing data\orchestra\grieg\grieg_waechter.mid
# Parsing data\orchestra\grieg\grieg_walzer.mid
# Parsing data\orchestra\grieg\grieg_wanderer.mid
# Parsing data\orchestra\grieg\grieg_wedding.mid
# Parsing data\orchestra\grieg\grieg_zwerge.mid
# Parsing data\orchestra\haydn\haydn_33_1.mid
# Parsing data\orchestra\haydn\haydn_33_2.mid
# Parsing data\orchestra\haydn\haydn_33_3.mid
# Parsing data\orchestra\haydn\haydn_35_1.mid
# Parsing data\orchestra\haydn\haydn_35_2.mid
# Parsing data\orchestra\haydn\haydn_35_3.mid
# Parsing data\orchestra\haydn\haydn_43_1.mid
# Parsing data\orchestra\haydn\haydn_43_2.mid
# Parsing data\orchestra\haydn\haydn_43_3.mid
# Parsing data\orchestra\haydn\haydn_7_1.mid
# Parsing data\orchestra\haydn\haydn_7_2.mid
# Parsing data\orchestra\haydn\haydn_7_3.mid
# Parsing data\orchestra\haydn\haydn_8_1.mid
# Parsing data\orchestra\haydn\haydn_8_2.mid
# Parsing data\orchestra\haydn\haydn_8_3.mid
# Parsing data\orchestra\haydn\haydn_8_4.mid
# Parsing data\orchestra\haydn\haydn_9_1.mid
# Parsing data\orchestra\haydn\haydn_9_2.mid
# Parsing data\orchestra\haydn\haydn_9_3.mid
# Parsing data\orchestra\haydn\hay_40_1.mid
# Parsing data\orchestra\haydn\hay_40_2.mid
# Parsing data\orchestra\liszt\liz_donjuan.mid
# Parsing data\orchestra\liszt\liz_et1.mid
# Parsing data\orchestra\liszt\liz_et2.mid
# Parsing data\orchestra\liszt\liz_et3.mid
# Parsing data\orchestra\liszt\liz_et4.mid
# Parsing data\orchestra\liszt\liz_et5.mid
# Parsing data\orchestra\liszt\liz_et6.mid
# Parsing data\orchestra\liszt\liz_et_trans4.mid
# Parsing data\orchestra\liszt\liz_et_trans5.mid
# Parsing data\orchestra\liszt\liz_et_trans8.mid
# Parsing data\orchestra\liszt\liz_liebestraum.mid
# Parsing data\orchestra\liszt\liz_rhap02.mid
# Parsing data\orchestra\liszt\liz_rhap09.mid
# Parsing data\orchestra\liszt\liz_rhap10.mid
# Parsing data\orchestra\liszt\liz_rhap12.mid
# Parsing data\orchestra\liszt\liz_rhap15.mid
# Parsing data\orchestra\mendelssohn\mendel_op19_1.mid
# Parsing data\orchestra\mendelssohn\mendel_op19_2.mid
# Parsing data\orchestra\mendelssohn\mendel_op19_3.mid
# Parsing data\orchestra\mendelssohn\mendel_op19_4.mid
# Parsing data\orchestra\mendelssohn\mendel_op19_5.mid
# Parsing data\orchestra\mendelssohn\mendel_op19_6.mid
# Parsing data\orchestra\mendelssohn\mendel_op30_1.mid
# Parsing data\orchestra\mendelssohn\mendel_op30_2.mid
# Parsing data\orchestra\mendelssohn\mendel_op30_3.mid
# Parsing data\orchestra\mendelssohn\mendel_op30_4.mid
# Parsing data\orchestra\mendelssohn\mendel_op30_5.mid
# Parsing data\orchestra\mendelssohn\mendel_op53_5.mid
# Parsing data\orchestra\mendelssohn\mendel_op62_3.mid
# Parsing data\orchestra\mendelssohn\mendel_op62_4.mid
# Parsing data\orchestra\mendelssohn\mendel_op62_5.mid
# Parsing data\orchestra\mozart\mz_311_1.mid
# Parsing data\orchestra\mozart\mz_311_2.mid
# Parsing data\orchestra\mozart\mz_311_3.mid
# Parsing data\orchestra\mozart\mz_330_1.mid
# Parsing data\orchestra\mozart\mz_330_2.mid
# Parsing data\orchestra\mozart\mz_330_3.mid
# Parsing data\orchestra\mozart\mz_331_1.mid
# Parsing data\orchestra\mozart\mz_331_2.mid
# Parsing data\orchestra\mozart\mz_331_3.mid
# Parsing data\orchestra\mozart\mz_332_1.mid
# Parsing data\orchestra\mozart\mz_332_2.mid
# Parsing data\orchestra\mozart\mz_332_3.mid
# Parsing data\orchestra\mozart\mz_333_1.mid
# Parsing data\orchestra\mozart\mz_333_2.mid
# Parsing data\orchestra\mozart\mz_333_3.mid
# Parsing data\orchestra\mozart\mz_545_1.mid
# Parsing data\orchestra\mozart\mz_545_2.mid
# Parsing data\orchestra\mozart\mz_545_3.mid
# Parsing data\orchestra\mozart\mz_570_1.mid
# Parsing data\orchestra\mozart\mz_570_2.mid
# Parsing data\orchestra\mozart\mz_570_3.mid
# Parsing data\orchestra\muss\muss_1.mid
# Parsing data\orchestra\muss\muss_2.mid
# Parsing data\orchestra\muss\muss_3.mid
# Parsing data\orchestra\muss\muss_4.mid
# Parsing data\orchestra\muss\muss_5.mid
# Parsing data\orchestra\muss\muss_6.mid
# Parsing data\orchestra\muss\muss_7.mid
# Parsing data\orchestra\muss\muss_8.mid
# Parsing data\orchestra\schubert\schubert_D850_1.mid
# Parsing data\orchestra\schubert\schubert_D850_2.mid
# Parsing data\orchestra\schubert\schubert_D850_3.mid
# Parsing data\orchestra\schubert\schubert_D850_4.mid
# Parsing data\orchestra\schubert\schubert_D935_1.mid
# Parsing data\orchestra\schubert\schubert_D935_2.mid
# Parsing data\orchestra\schubert\schubert_D935_3.mid
# Parsing data\orchestra\schubert\schubert_D935_4.mid
# Parsing data\orchestra\schubert\schub_d760_1.mid
# Parsing data\orchestra\schubert\schub_d760_2.mid
# Parsing data\orchestra\schubert\schub_d760_3.mid
# Parsing data\orchestra\schubert\schub_d760_4.mid
# Parsing data\orchestra\schubert\schub_d960_1.mid
# Parsing data\orchestra\schubert\schub_d960_2.mid
# Parsing data\orchestra\schubert\schub_d960_3.mid
# Parsing data\orchestra\schubert\schub_d960_4.mid
# Parsing data\orchestra\schubert\schuim-1.mid
# Parsing data\orchestra\schubert\schuim-2.mid
# Parsing data\orchestra\schubert\schuim-3.mid
# Parsing data\orchestra\schubert\schuim-4.mid
# Parsing data\orchestra\schubert\schumm-1.mid
# Parsing data\orchestra\schubert\schumm-2.mid
# Parsing data\orchestra\schubert\schumm-3.mid
# Parsing data\orchestra\schubert\schumm-4.mid
# Parsing data\orchestra\schubert\schumm-5.mid
# Parsing data\orchestra\schubert\schumm-6.mid
# Parsing data\orchestra\schubert\schu_143_1.mid
# Parsing data\orchestra\schubert\schu_143_2.mid
# Parsing data\orchestra\schubert\schu_143_3.mid
# Parsing data\orchestra\schumann\schum_abegg.mid
# Parsing data\orchestra\schumann\scn15_1.mid
# Parsing data\orchestra\schumann\scn15_10.mid
# Parsing data\orchestra\schumann\scn15_11.mid
# Parsing data\orchestra\schumann\scn15_12.mid
# Parsing data\orchestra\schumann\scn15_13.mid
# Parsing data\orchestra\schumann\scn15_2.mid
# Parsing data\orchestra\schumann\scn15_3.mid
# Parsing data\orchestra\schumann\scn15_4.mid
# Parsing data\orchestra\schumann\scn15_5.mid
# Parsing data\orchestra\schumann\scn15_6.mid
# Parsing data\orchestra\schumann\scn15_7.mid
# Parsing data\orchestra\schumann\scn15_8.mid
# Parsing data\orchestra\schumann\scn15_9.mid
# Parsing data\orchestra\schumann\scn16_1.mid
# Parsing data\orchestra\schumann\scn16_2.mid
# Parsing data\orchestra\schumann\scn16_3.mid
# Parsing data\orchestra\schumann\scn16_4.mid
# Parsing data\orchestra\schumann\scn16_5.mid
# Parsing data\orchestra\schumann\scn16_6.mid
# Parsing data\orchestra\schumann\scn16_7.mid
# Parsing data\orchestra\schumann\scn16_8.mid
# Parsing data\orchestra\schumann\scn68_10.mid
# Parsing data\orchestra\schumann\scn68_12.mid
# Parsing data\orchestra\tschai\ty_april.mid
# Parsing data\orchestra\tschai\ty_august.mid
# Parsing data\orchestra\tschai\ty_dezember.mid
# Parsing data\orchestra\tschai\ty_februar.mid
# Parsing data\orchestra\tschai\ty_januar.mid
# Parsing data\orchestra\tschai\ty_juli.mid
# Parsing data\orchestra\tschai\ty_juni.mid
# Parsing data\orchestra\tschai\ty_maerz.mid
# Parsing data\orchestra\tschai\ty_mai.mid
# Parsing data\orchestra\tschai\ty_november.mid
# Parsing data\orchestra\tschai\ty_oktober.mid
# Parsing data\orchestra\tschai\ty_september.mid

# %%
class Notes:
    def __init__(self, notes):
        self.notes = notes
        notes = sorted(notes, key=lambda x: x.start)

        # first note is the one with the earliest start time
        self.first_note = notes[0]
        self.start = self.first_note.start

        notes = sorted(notes, key=lambda x: x.end)
        #last note is the one with the latest end time
        self.last_note = notes[-1]
        self.end = self.last_note.end
        self.duration = self.end - self.start
        self.parse_notes()
        
    def parse_notes(self):
        for note in self.notes:
            note.start -= self.start
            note.end -= self.start
            
    def __repr__(self) -> str:
        return f"Notes: len={len(self.notes)}, start={self.start}, end={self.end}, duration={self.duration}"
    
    def get_last_notes(self, n):
        if len(self.notes) < n:
            return self.notes
        return self.notes[-n:]

# %%
artist_notes = {key: [[Notes(notes) for notes in song] for song in training_notes] for key, training_notes in artist_notes.items()}

# %%
artist_notes = {key:[item for sublist in training_notes for item in sublist] for key, training_notes in artist_notes.items()}

# %%
def make_previous_tuple(notes):
    for i in range(len(notes)-1):
        yield ((notes[i], i), 
               (notes[i+1], i+1))
        
previous_artist_notes = {key:make_previous_tuple(training_notes) for key, training_notes in artist_notes.items()}

# %%
artist_note_dicts = {}

for artist, previous_notes in previous_artist_notes.items():
    
    note_dict = {}

    for (note_1, _), (note_2, idx) in previous_notes:
        key = (note_1.last_note.pitch)
        if key in note_dict.keys():
            note_dict[key].append((note_2, idx))
        else:
            note_dict[key] = [(note_2, idx)]
            
    artist_note_dicts[artist] = note_dict

# %%
artist_note_dicts['Bach']
# Out:
# {76: [(Notes: len=3, start=1.0111756895833335, end=1.6192839395833336, duration=0.6081082500000001,
#    1),
#   (Notes: len=3, start=2.0246894395833337, end=2.612527414583334, duration=0.5878379750000002,
#    2),
#   (Notes: len=3, start=2.6327751666666668, end=3.2327976895833337, duration=0.6000225229166669,
#    3),
#   (Notes: len=3, start=3.6382031895833338, end=4.211264789583333, duration=0.5730615999999991,
#    4),
#   (Notes: len=3, start=10.542302737499996, end=11.141121487499996, duration=0.5988187499999995,
#    13),
#   (Notes: len=3, start=11.535858487499997, end=12.10363028958333, duration=0.5677718020833336,
#    14),
#   (Notes: len=3, start=12.122903237499996, end=12.71505318958333, duration=0.592149952083334,
#    15),
#   (Notes: len=3, start=13.12045868958333, end=13.693520289583331, duration=0.5730616000000008,
#    16)],
#  77: [(Notes: len=3, start=4.230537737500001, end=4.822654129166667, duration=0.5921163916666661,
#    5),
#   (Notes: len=3, start=5.220005129166666, end=5.784298679166667, duration=0.5642935500000004,
#    6),
#   (Notes: len=3, start=5.803327127083333, end=6.395694852083333, duration=0.5923677250000008,
#    7),
#   (Notes: len=3, start=6.798379352083333, end=7.3631614999999995, duration=0.5647821479166666,
#    8),
#   (Notes: len=3, start=7.381972377083333, end=7.966442602083333, duration=0.5844702250000005,
#    9),
#   (Notes: len=3, start=8.369127102083333, end=8.940839539583333, duration=0.5717124375000004,
#    10),
#   (Notes: len=3, start=8.960112487499998, end=9.561745987499997, duration=0.6016334999999984,
#    11),
#   (Notes: len=3, start=9.956482987499998, end=10.523142081249997, duration=0.5666590937499993,
#    12)],
#  81: [(Notes: len=3, start=13.712782487499997, end=14.30107318958333, duration=0.5882907020833326,
#    17),
#   (Notes: len=3, start=14.70647868958333, end=15.278250289583331, duration=0.5717716000000017,
#    18),
#   (Notes: len=3, start=15.297512487499997, end=15.891011737499996, duration=0.5934992499999989,
#    19),
#   (Notes: len=3, start=16.283168737499995, end=16.847258581249996, duration=0.5640898437500006,
#    20)],
#  74: [(Notes: len=3, start=16.86639787708333, end=17.45086810208333, duration=0.5844702250000005,
#    21),
#   (Notes: len=3, start=17.85355260208333, end=18.43150735208333, duration=0.57795475,
#    22),
#   (Notes: len=3, start=18.450987877083328, end=19.047538166666662, duration=0.5965502895833339,
#    23),
#   (Notes: len=3, start=19.447538166666664, end=20.015356289583334, duration=0.5678181229166697,
#    24),
#   (Notes: len=3, start=39.14497682083335, end=39.733233962500016, duration=0.5882571416666664,
#    49),
#   (Notes: len=3, start=40.130584962500016, end=40.70438497083335, duration=0.5738000083333361,
#    50),
#   (Notes: len=3, start=40.72399282083335, end=41.324515750000025, duration=0.6005229291666723,
#    51),
#   (Notes: len=3, start=41.72451575000002, end=42.300953720833355, duration=0.5764379708333323,
#    52)],
#  79: [(Notes: len=3, start=20.034607877083335, end=20.626964416666667, duration=0.5923565395833315,
#    25),
#   (Notes: len=3, start=21.02696441666667, end=21.59465280416667, duration=0.5676883875000023,
#    26),
#   (Notes: len=3, start=21.61400765416667, end=22.208066102083336, duration=0.594058447916666,
#    27),
#   (Notes: len=3, start=22.610750602083336, end=23.18756380416667, duration=0.5768132020833328,
#    28)],
#  72: [(Notes: len=3, start=23.206918654166667, end=23.796739487500002, duration=0.5898208333333343,
#    29),
#   (Notes: len=3, start=24.188896487500003, end=24.755226054166666, duration=0.5663295666666635,
#    30),
#   (Notes: len=3, start=24.774580904166665, end=25.3686062375, duration=0.5940253333333345,
#    31),
#   (Notes: len=3, start=25.7633432375, end=26.335711887499997, duration=0.5723686499999978,
#    32),
#   (Notes: len=3, start=26.355493189583335, end=26.963567879166668, duration=0.6080746895833329,
#    33),
#   (Notes: len=3, start=27.360918879166668, end=27.937077829166668, duration=0.57615895,
#    34),
#   (Notes: len=3, start=27.956990431250002, end=28.584131931250003, duration=0.6271415000000005,
#    35),
#   (Notes: len=3, start=28.992295431250003, end=29.57634316666667, duration=0.584047735416668,
#    36),
#   (Notes: len=3, start=29.59634316666667, end=30.196377181250003, duration=0.6000340145833327,
#    37),
#   (Notes: len=3, start=30.604540681250004, end=31.18606082916667, duration=0.5815201479166667,
#    38),
#   (Notes: len=3, start=31.20592837916667, end=31.81017587916667, duration=0.6042474999999996,
#    39),
#   (Notes: len=3, start=32.20752687916667, end=32.7813268875, duration=0.573800008333329,
#    40),
#   (Notes: len=3, start=45.49471498750003, end=46.07540321250003, duration=0.5806882249999958,
#    57),
#   (Notes: len=3, start=46.47275421250003, end=47.0453976854167, duration=0.5726434729166741,
#    58),
#   (Notes: len=3, start=47.0648782104167, end=47.665810685416695, duration=0.6009324749999934,
#    59),
#   (Notes: len=3, start=48.068495185416694, end=48.64760647083336, duration=0.5791112854166656,
#    60)],
#  71: [(Notes: len=3, start=32.8009347375, end=33.38919187916667, duration=0.5882571416666664,
#    41),
#   (Notes: len=3, start=33.78654287916667, end=34.35918635208334, duration=0.5726434729166741,
#    42),
#   (Notes: len=3, start=34.37866687708334, end=34.96969612916667, duration=0.5910292520833309,
#    43),
#   (Notes: len=3, start=35.36704712916667, end=35.939690602083346, duration=0.5726434729166741,
#    44),
#   (Notes: len=3, start=42.320561570833355, end=42.908829750000024, duration=0.5882681791666684,
#    53),
#   (Notes: len=3, start=43.30882975000002, end=43.885267720833355, duration=0.5764379708333323,
#    54),
#   (Notes: len=3, start=43.904875570833354, end=44.50254475000003, duration=0.5976691791666724,
#    55),
#   (Notes: len=3, start=44.902544750000025, end=45.47536013750003, duration=0.5728153875000075,
#    56)],
#  73: [(Notes: len=3, start=35.959171127083344, end=36.55571037916667, duration=0.5965392520833248,
#    45),
#   (Notes: len=3, start=36.95306137916667, end=37.52729422083334, duration=0.5742328416666709,
#    46),
#   (Notes: len=3, start=37.54690207083334, end=38.14464069375001, duration=0.5977386229166726,
#    47),
#   (Notes: len=3, start=38.55156896250001, end=39.12536897083335, duration=0.5738000083333361,
#    48)],
#  65: [(Notes: len=3, start=48.66721432083336, end=49.255493685416695, duration=0.588279364583336,
#    61),
#   (Notes: len=3, start=49.658178185416695, end=50.238461220833365, duration=0.5802830354166701,
#    62),
#   (Notes: len=3, start=50.25819807083336, end=50.8657341854167, duration=0.6075361145833398,
#    63),
#   (Notes: len=3, start=51.2684186854167, end=51.84870172083337, duration=0.5802830354166701,
#    64),
#   (Notes: len=3, start=51.86843857083336, end=52.4744761854167, duration=0.6060376145833359,
#    65),
#   (Notes: len=3, start=52.8771606854167, end=53.458630912500034, duration=0.5814702270833365,
#    66),
#   (Notes: len=3, start=53.47849846250003, end=54.0886376854167, duration=0.610139222916672,
#    67),
#   (Notes: len=3, start=54.4913221854167, end=55.0752147104167, duration=0.5838925250000031,
#    68),
#   (Notes: len=3, start=55.0953489354167, end=55.6993756854167, duration=0.6040267499999956,
#    69),
#   (Notes: len=3, start=56.1020601854167, end=56.6859527104167, duration=0.5838925250000031,
#    70),
#   (Notes: len=3, start=56.7060869354167, end=57.31015997083337, duration=0.6040730354166683,
#    71),
#   (Notes: len=3, start=57.723952970833366, end=58.3133534604167, duration=0.5894004895833334,
#    72),
#   (Notes: len=3, start=80.74940714791666, end=81.33819102291665, duration=0.5887838749999901,
#    101),
#   (Notes: len=3, start=81.73953571249999, end=82.30991062291665, duration=0.5703749104166604,
#    102),
#   (Notes: len=3, start=82.32914139791664, end=82.92038921249997, duration=0.5912478145833262,
#    103),
#   (Notes: len=3, start=83.31774021249997, end=83.89038368541664, duration=0.572643472916667,
#    104),
#   (Notes: len=3, start=83.90986421041664, end=84.49431221249998, duration=0.5844480020833345,
#    105),
#   (Notes: len=3, start=84.89166321249998, end=85.46430668541664, duration=0.572643472916667,
#    106),
#   (Notes: len=3, start=85.48378721041665, end=86.07890946249998, duration=0.5951222520833284,
#    107),
#   (Notes: len=3, start=86.47626046249998, end=87.05241941249999, duration=0.576158950000007,
#    108),
#   (Notes: len=3, start=93.59275207083333, end=94.18102024999999, duration=0.5882681791666613,
#    117),
#   (Notes: len=3, start=94.58102025, end=95.16102024999999, duration=0.5799999999999983,
#    118),
#   (Notes: len=3, start=95.18098757083332, end=95.76936213333332, duration=0.5883745624999932,
#    119),
#   (Notes: len=3, start=96.18202174999999, end=96.76202174999999, duration=0.5799999999999983,
#    120),
#   (Notes: len=3, start=96.78202174999998, end=97.38210333541666, duration=0.6000815854166746,
#    121),
#   (Notes: len=3, start=97.79316543541665, end=98.37705796041666, duration=0.5838925250000102,
#    122),
#   (Notes: len=3, start=98.39719218541666, end=99.00124176458333, duration=0.60404957916667,
#    123),
#   (Notes: len=3, start=99.40940526458333, end=99.99875396041666, duration=0.5893486958333369,
#    124),
#   (Notes: len=16, start=3.6982157520833328, end=5.542322300000001, duration=1.8441065479166685,
#    132),
#   (Notes: len=40, start=5.543368325000001, end=10.17632041666667, duration=4.632952091666668,
#    133),
#   (Notes: len=16, start=17.490840954166668, end=19.32531685416667, duration=1.834475900000001,
#    136)],
#  64: [(Notes: len=3, start=58.3334876854167, end=58.937548912500034, duration=0.604061227083335,
#    73),
#   (Notes: len=3, start=59.34850791250003, end=59.93394175000004, duration=0.5854338375000054,
#    74),
#   (Notes: len=3, start=59.953941750000034, end=60.553941750000035, duration=0.6000000000000014,
#    75),
#   (Notes: len=3, start=60.953941750000034, end=61.529223185416704, duration=0.5752814354166702,
#    76),
#   (Notes: len=3, start=61.54873596250003, end=62.144773500000035, duration=0.5960375375000027,
#    77),
#   (Notes: len=3, start=62.54477350000003, end=63.120054935416704, duration=0.5752814354166702,
#    78),
#   (Notes: len=3, start=63.139578750000034, end=63.75855675000003, duration=0.6189779999999985,
#    79),
#   (Notes: len=3, start=64.15855675000003, end=64.73499472083337, duration=0.5764379708333394,
#    80),
#   (Notes: len=3, start=64.75460257083337, end=65.34287075000003, duration=0.5882681791666613,
#    81),
#   (Notes: len=3, start=65.74287075000004, end=66.32048047083336, duration=0.5776097208333226,
#    82),
#   (Notes: len=3, start=66.34021732083336, end=66.95083751458337, duration=0.6106201937500089,
#    83),
#   (Notes: len=3, start=67.35900101458337, end=67.94834971041671, duration=0.5893486958333369,
#    84),
#   (Notes: len=3, start=77.58587907083333, end=78.17801768541666, duration=0.5921386145833338,
#    97),
#   (Notes: len=3, start=78.58070218541667, end=79.15981347083333, duration=0.5791112854166585,
#    98),
#   (Notes: len=3, start=79.17942132083333, end=79.76766757083332, duration=0.5882462499999974,
#    99),
#   (Notes: len=3, start=80.16240457083332, end=80.73017637291666, duration=0.5677718020833424,
#    100),
#   (Notes: len=3, start=100.01888818541666, end=100.63436151458333, duration=0.6154733291666759,
#    125),
#   (Notes: len=3, start=101.04252501458333, end=101.63187371041667, duration=0.5893486958333369,
#    126),
#   (Notes: len=3, start=101.65200793541666, end=102.26450551458333, duration=0.6124975791666714,
#    127),
#   (Notes: len=14, start=102.67096833333333, end=105.595360875, duration=2.9243925416666627,
#    128),
#   (Notes: len=32, start=13.81765595416667, end=17.488895429166668, duration=3.6712394749999984,
#    135),
#   (Notes: len=57, start=63.19301263541669, end=71.26584479166668, duration=8.072832156249987,
#    156),
#   (Notes: len=28, start=53.61397047916665, end=56.06031862499999, duration=2.4463481458333334,
#    158)],
#  63: [(Notes: len=3, start=67.9684839354167, end=68.57253351458337, duration=0.60404957916667,
#    85),
#   (Notes: len=3, start=68.98069701458337, end=69.56882650000004, duration=0.5881294854166725,
#    86),
#   (Notes: len=3, start=69.58882650000004, end=70.22317957083337, duration=0.6343530708333276,
#    87),
#   (Notes: len=3, start=70.61791657083336, end=71.19028522083336, duration=0.5723686500000014,
#    88),
#   (Notes: len=24, start=0.9283729375, end=3.6952153708333326, duration=2.7668424333333324,
#    131),
#   (Notes: len=32, start=35.00386724375001, end=38.69738363333334, duration=3.69351638958333,
#    146)],
#  62: [(Notes: len=3, start=71.2099798979167, end=71.80011707083335, duration=0.5901371729166556,
#    89),
#   (Notes: len=3, start=72.19485407083334, end=72.76722272083335, duration=0.5723686500000014,
#    90),
#   (Notes: len=3, start=72.78692773750001, end=73.37819426458334, duration=0.5912665270833344,
#    91),
#   (Notes: len=3, start=73.78635776458334, end=74.36538372083335, duration=0.5790259562500069,
#    92),
#   (Notes: len=3, start=74.38512057083334, end=74.97727052291667, duration=0.5921499520833322,
#    93),
#   (Notes: len=3, start=75.38267602291667, end=75.96033447083335, duration=0.5776584479166758,
#    94),
#   (Notes: len=3, start=75.98007132083333, end=76.58317468541667, duration=0.6031033645833332,
#    95),
#   (Notes: len=3, start=76.98585918541667, end=77.56614222083333, duration=0.5802830354166559,
#    96),
#   (Notes: len=8, start=0.003061225, end=0.9243444375000001, duration=0.9212832125000001,
#    130),
#   (Notes: len=8, start=23.933251208333335, end=24.859674583333337, duration=0.9264233750000024,
#    139),
#   (Notes: len=8, start=29.47008332708333, end=30.391854566666666, duration=0.921771239583336,
#    142),
#   (Notes: len=8, start=30.39381927083333, end=31.31732364166666, duration=0.9235043708333315,
#    143),
#   (Notes: len=16, start=31.318344049999997, end=33.166095116666675, duration=1.847751066666678,
#    144),
#   (Notes: len=16, start=59.25858663541669, end=63.008586416666695, duration=3.749999781250004,
#    155),
#   (Notes: len=4, start=56.26865187499999, end=56.476985124999985, duration=0.20833324999999547,
#    159)],
#  66: [(Notes: len=3, start=87.07233201458331, end=87.68453221249997, duration=0.612200197916664,
#    109),
#   (Notes: len=3, start=88.08188321249997, end=88.65804216249998, duration=0.576158950000007,
#    110),
#   (Notes: len=3, start=88.67796641249997, end=89.30639004791665, duration=0.6284236354166808,
#    111),
#   (Notes: len=3, start=89.73496154791665, end=90.32912824999998, duration=0.5941667020833279,
#    112),
#   (Notes: len=32, start=10.17832041666667, end=13.81571785416667, duration=3.637397437499999,
#    134)],
#  67: [(Notes: len=3, start=90.34912824999999, end=90.94920983541665, duration=0.6000815854166603,
#    113),
#   (Notes: len=3, start=91.36879033541666, end=91.95849899999999, duration=0.5897086645833269,
#    114),
#   (Notes: len=3, start=91.978499, end=92.59278474999999, duration=0.6142857499999934,
#    115),
#   (Notes: len=3, start=92.99278475, end=93.57278475, duration=0.5799999999999983,
#    116),
#   (Notes: len=8, start=19.32922310416667, end=20.249474752083334, duration=0.9202516479166647,
#    137),
#   (Notes: len=32, start=20.2505523375, end=23.932222402083337, duration=3.6816700645833365,
#    138)],
#  50: [(Notes: len=14, start=106.017895875, end=109.63545758333335, duration=3.617561708333355,
#    129),
#   (Notes: len=511, start=0.10791375, end=53.353553916666655, duration=53.245640166666654,
#    157)],
#  58: [(Notes: len=24, start=24.861658708333337, end=27.614865785416665, duration=2.753207077083328,
#    140)],
#  60: [(Notes: len=16, start=27.61710793958333, end=29.46790941458333, duration=1.8508014749999973,
#    141),
#   (Notes: len=16, start=33.167158945833336, end=35.000726362500004, duration=1.8335674166666678,
#    145),
#   (Notes: len=8, start=38.69840404166668, end=39.627574020833336, duration=0.9291699791666588,
#    147),
#   (Notes: len=24, start=39.630583104166675, end=42.381950700000004, duration=2.7513675958333295,
#    148),
#   (Notes: len=8, start=42.38293884166667, end=43.28801439166667, duration=0.9050755499999994,
#    149),
#   (Notes: len=8, start=43.289959916666675, end=44.21124840000001, duration=0.9212884833333348,
#    150),
#   (Notes: len=13, start=44.580431416666684, end=46.088153916666684, duration=1.5077224999999999,
#    151),
#   (Notes: len=95, start=49.892491125000014, end=59.07416041666669, duration=9.18166929166668,
#    154)],
#  53: [(Notes: len=13, start=46.45124991666668, end=47.956236416666684, duration=1.5049865000000011,
#    152)],
#  56: [(Notes: len=13, start=48.30653987500001, end=49.79508862500001, duration=1.4885487499999996,
#    153)],
#  82: [(Notes: len=4, start=57.101984874999985, end=57.31031812499999, duration=0.20833325000000258,
#    160)]}

# %%
chains = {key: [(artist_notes[key][0], 0)] for key in artist_notes.keys()}
n_words = 500

# %%
chains
# Out:
# {'Bach': [(Notes: len=3, start=0.4070946895833334, end=0.9912745791666667, duration=0.5841798895833333,
#    0)],
#  'Mozart': [(Notes: len=3, start=0.0, end=0.42304200000000003, duration=0.42304200000000003,
#    0)],
#  'Schumann x Chopin': [(Notes: len=160, start=0.75, end=40.8277393333333, duration=40.0777393333333,
#    0)],
#  'Debussy x Albeniz': [(Notes: len=95, start=0.12211000000000001, end=11.671070560416666, duration=11.548960560416667,
#    0)],
#  'All': [(Notes: len=18, start=0.321096, end=6.813055, duration=6.4919590000000005,
#    0)]}

# %%
len(artist_notes['Bach'])
# Out:
# 161

# %%
complete_chains = {}
for artist, chain in chains.items():
    complete_chain = chain.copy()
    for i in range(n_words):
        notes_1, idx = complete_chain[-1]
        prob = np.random.random()
        if prob < 0.5 or (notes_1.last_note.pitch) not in artist_note_dicts[artist].keys():
            if idx + 1 >= len(artist_notes[artist]):
                complete_chain.append((Notes([pretty_midi.Note(0, 0, 0, 1)]), -1))
                continue
            new_note = artist_notes[artist][idx + 1]
            complete_chain.append((new_note, idx + 1))
            continue
        
        selected = artist_note_dicts[artist][notes_1.last_note.pitch]
        idx = np.random.choice(len(selected))
        complete_chain.append(selected[idx])
    
    complete_chains[artist] = complete_chain

# %%
complete_chains['All']
# Out:
# [(Notes: len=18, start=0.321096, end=6.813055, duration=6.4919590000000005, 0),
#  (Notes: len=23, start=7.110205666666666, end=12.834832333333331, duration=5.724626666666665,
#   1),
#  (Notes: len=42, start=13.149153916666664, end=26.24811591666667, duration=13.098962000000006,
#   2),
#  (Notes: len=3, start=26.464332250000002, end=26.770845583333337, duration=0.30651333333333497,
#   3),
#  (Notes: len=3, start=26.941058250000005, end=27.24125108333334, duration=0.3001928333333339,
#   4),
#  (Notes: len=3, start=68.02060387291667, end=68.11361562291667, duration=0.09301175000000228,
#   1950),
#  (Notes: len=2, start=630.9633251270816, end=631.450593710415, duration=0.48726858333338896,
#   55158),
#  (Notes: len=3, start=53.645407750000004, end=54.631600875000004, duration=0.9861931249999998,
#   40285),
#  (Notes: len=4, start=47.036556802083304, end=47.214746302083306, duration=0.178189500000002,
#   14608),
#  (Notes: len=2, start=47.274142802083304, end=47.408143052083304, duration=0.1340002499999997,
#   14609),
#  (Notes: len=2, start=0.60956575, end=0.6629921875, duration=0.05342643749999998,
#   20993),
#  (Notes: len=1, start=0.8232715, end=0.9921675416666667, duration=0.1688960416666666,
#   20994),
#  (Notes: len=4, start=31.29269183333334, end=31.97470383333334, duration=0.6820120000000003,
#   57878),
#  (Notes: len=1, start=149.30968686875002, end=149.63877547708333, duration=0.3290886083333078,
#   15025),
#  (Notes: len=1, start=149.65639557708334, end=149.99527421041662, duration=0.3388786333332803,
#   15026),
#  (Notes: len=2, start=47.666629249999986, end=47.782863249999984, duration=0.11623399999999862,
#   56723),
#  (Notes: len=1, start=118.7541051854167, end=118.94518818541671, duration=0.1910830000000061,
#   6221),
#  (Notes: len=1, start=119.32735418541671, end=119.5184371854167, duration=0.1910829999999919,
#   6222),
#  (Notes: len=4, start=260.50183334999963, end=260.8166950999996, duration=0.3148617499999773,
#   8755),
#  (Notes: len=7, start=222.8493237500002, end=226.21750270833354, duration=3.3681789583333455,
#   20988),
#  (Notes: len=1, start=123.9672870999999, end=124.08872484999989, duration=0.12143774999999835,
#   20749),
#  (Notes: len=5, start=116.6380354125, end=117.1510094125, duration=0.5129739999999998,
#   41095),
#  (Notes: len=2, start=87.73427956249985, end=87.79783887499985, duration=0.06355931250000424,
#   30203),
#  (Notes: len=2, start=87.81902531249986, end=87.88258462499985, duration=0.06355931249999003,
#   30204),
#  (Notes: len=1, start=20.31755416666666, end=20.449712666666663, duration=0.13215850000000273,
#   395),
#  (Notes: len=7, start=227.86350673333376, end=228.45878573333377, duration=0.595279000000005,
#   40419),
#  (Notes: len=1, start=228.64865923333377, end=228.74359598333376, duration=0.09493674999998802,
#   40420),
#  (Notes: len=1, start=229.02840623333375, end=229.12334298333377, duration=0.09493675000001645,
#   40421),
#  (Notes: len=2, start=433.9465302749991, end=434.03056377499905, duration=0.08403349999997545,
#   33692),
#  (Notes: len=2, start=434.07258052499907, end=434.1589655249991, duration=0.08638500000000704,
#   33693),
#  (Notes: len=4, start=107.78379714583336, end=108.40129564583337, duration=0.6174985000000106,
#   37405),
#  (Notes: len=4, start=108.52369964583337, end=109.14092614583338, duration=0.617226500000001,
#   37406),
#  (Notes: len=10, start=109.26333014583338, end=110.59527880208336, duration=1.3319486562499776,
#   37407),
#  (Notes: len=4, start=110.71768280208335, end=111.33518130208336, duration=0.6174985000000106,
#   37408),
#  (Notes: len=3, start=10.121176283333336, end=10.193523533333336, duration=0.07234724999999997,
#   32439),
#  (Notes: len=1, start=51.417998729166584, end=51.50179772916659, duration=0.08379900000000617,
#   45638),
#  (Notes: len=163, start=41.59969373333337, end=67.3110083375, duration=25.71131460416663,
#   565),
#  (Notes: len=3, start=245.7759579166669, end=246.0894049166669, duration=0.3134469999999965,
#   51375),
#  (Notes: len=1, start=43.362465749999984, end=43.43746574999999, duration=0.07500000000000284,
#   25062),
#  (Notes: len=1, start=43.66246574999999, end=43.738607999999985, duration=0.07614224999999664,
#   25063),
#  (Notes: len=3, start=237.75557565833265, end=237.83410965833264, duration=0.07853399999999056,
#   57640),
#  (Notes: len=2, start=290.5873849312504, end=290.6778104812504, duration=0.09042554999996355,
#   32050),
#  (Notes: len=3, start=946.646920204163, end=946.7200909541631, duration=0.07317075000003115,
#   27844),
#  (Notes: len=3, start=946.793261704163, end=946.866432454163, duration=0.07317075000003115,
#   27845),
#  (Notes: len=7, start=946.9396032041631, end=947.932220204163, duration=0.992616999999882,
#   27846),
#  (Notes: len=5, start=78.06909761666668, end=79.12146595000002, duration=1.0523683333333338,
#   18995),
#  (Notes: len=3, start=79.37314395000001, end=80.40853003333335, duration=1.0353860833333357,
#   18996),
#  (Notes: len=8, start=80.61734720000001, end=81.67149545, duration=1.054148249999983,
#   18997),
#  (Notes: len=2, start=81.88654944999999, end=82.43740944999999, duration=0.5508600000000001,
#   18998),
#  (Notes: len=1, start=156.97171486874998, end=157.13564936875, duration=0.16393450000001053,
#   6555),
#  (Notes: len=1, start=157.29958386874998, end=157.47069936875, duration=0.1711155000000133,
#   6556),
#  (Notes: len=2, start=157.64181486874998, end=158.30479886874997, duration=0.6629839999999945,
#   6557),
#  (Notes: len=5, start=158.79714886874996, end=159.60621036874997, duration=0.8090615000000128,
#   6558),
#  (Notes: len=1, start=26.72099820833334, end=26.83129233333334, duration=0.11029412499999935,
#   39838),
#  (Notes: len=13, start=27.162174708333342, end=30.300217218750014, duration=3.138042510416671,
#   39839),
#  (Notes: len=1, start=3.84403975, end=3.94656875, duration=0.10252900000000009,
#   44304),
#  (Notes: len=4, start=82.70725743750005, end=83.30321687500005, duration=0.5959594374999995,
#   22979),
#  (Notes: len=2, start=416.58591499166573, end=416.77030598124907, duration=0.18439098958333489,
#   10196),
#  (Notes: len=502, start=169.2974382124999, end=229.10126571249984, duration=59.803827499999926,
#   555),
#  (Notes: len=2, start=141.03571994166657, end=141.88180394166656, duration=0.8460839999999905,
#   41337),
#  (Notes: len=2, start=142.30484594166657, end=143.15092994166656, duration=0.8460839999999905,
#   41338),
#  (Notes: len=7, start=121.8677795291667, end=122.5455572791667, duration=0.6777777500000042,
#   20932),
#  (Notes: len=1, start=33.32119680833335, end=33.491651308333346, duration=0.17045449999999818,
#   58040),
#  (Notes: len=1, start=33.66146743333334, end=33.830006808333344, duration=0.1685393750000017,
#   58041),
#  (Notes: len=1, start=65.04663970833334, end=65.15558795833334, duration=0.10894824999999742,
#   39195),
#  (Notes: len=1, start=65.26500345833334, end=65.38204470833334, duration=0.11704124999999976,
#   39196),
#  (Notes: len=3, start=65.49462029166666, end=66.18000279166667, duration=0.6853825000000029,
#   39197),
#  (Notes: len=5, start=66.41540779166667, end=67.17320241666667, duration=0.7577946250000025,
#   39198),
#  (Notes: len=1, start=126.20185622499996, end=126.32792772499997, duration=0.126071500000009,
#   259),
#  (Notes: len=1, start=5.73584275, end=6.08676075, duration=0.35091800000000006,
#   24419),
#  (Notes: len=2, start=82.83763308541664, end=83.79266454166664, duration=0.9550314562499977,
#   24283),
#  (Notes: len=14, start=254.3877500833338, end=256.8982845833338, duration=2.5105345000000057,
#   48486),
#  (Notes: len=1, start=321.80351477916696, end=321.8961072791669, duration=0.09259249999996655,
#   43345),
#  (Notes: len=8, start=321.9269714458336, end=322.8679025291669, duration=0.9409310833332825,
#   43346),
#  (Notes: len=1, start=322.89857736250025, end=322.9906018625002, duration=0.09202449999997953,
#   43347),
#  (Notes: len=1, start=323.02127669583354, end=323.11330119583357, duration=0.09202450000003637,
#   43348),
#  (Notes: len=1, start=323.1439760291669, end=323.2360005291669, duration=0.09202450000003637,
#   43349),
#  (Notes: len=3, start=100.65786212499982, end=100.72474887499982, duration=0.06688674999999478,
#   54443),
#  (Notes: len=5, start=100.79163562499981, end=101.1241936249998, duration=0.3325579999999917,
#   54444),
#  (Notes: len=2, start=101.1912536249998, end=101.2583136249998, duration=0.0670599999999979,
#   54445),
#  (Notes: len=5, start=101.32537362499981, end=101.6577583749998, duration=0.33238474999998857,
#   54446),
#  (Notes: len=5, start=101.72464512499981, end=102.11838541666647, duration=0.3937402916666599,
#   54447),
#  (Notes: len=2, start=102.1239166249998, end=102.19203662499979, duration=0.0681199999999933,
#   54448),
#  (Notes: len=2, start=102.2601566249998, end=102.32827662499979, duration=0.0681199999999933,
#   54449),
#  (Notes: len=1, start=20.839087333333318, end=20.94329468541665, duration=0.10420735208333198,
#   16863),
#  (Notes: len=1, start=20.944125249999985, end=21.04296243541665, duration=0.09883718541666653,
#   16864),
#  (Notes: len=1, start=21.043792999999983, end=21.14252293541665, duration=0.0987299354166673,
#   16865),
#  (Notes: len=1, start=118.33652085416664, end=118.41553135416663, duration=0.07901049999999543,
#   30825),
#  (Notes: len=1, start=118.41825585416663, end=118.68646410416663, duration=0.2682082500000007,
#   30826),
#  (Notes: len=2, start=363.7578624624997, end=363.8957807124997, duration=0.13791824999998425,
#   53195),
#  (Notes: len=4, start=210.28725574999962, end=210.4223909999996, duration=0.1351352499999905,
#   53024),
#  (Notes: len=2, start=369.6761240458329, end=369.8127112958329, duration=0.13658724999999095,
#   53227),
#  (Notes: len=1, start=321.00276433333374, end=321.1611593333337, duration=0.15839499999998452,
#   48586),
#  (Notes: len=4, start=321.3351733333337, end=321.82004608333375, duration=0.4848727500000223,
#   48587),
#  (Notes: len=1, start=321.97597133333375, end=322.13189658333374, duration=0.15592524999999569,
#   48588),
#  (Notes: len=4, start=288.0937205708328, end=289.1465510708328, duration=1.0528305000000273,
#   54809),
#  (Notes: len=27, start=220.57951862083357, end=221.6261434541669, duration=1.0466248333333397,
#   28462),
#  (Notes: len=4, start=221.99199720416692, end=222.16596864166692, duration=0.17397143750000055,
#   28463),
#  (Notes: len=2, start=265.5524347666658, end=265.61291864166583, duration=0.06048387500004537,
#   35778),
#  (Notes: len=2, start=265.6734025166658, end=265.7338863916658, duration=0.06048387499998853,
#   35779),
#  (Notes: len=3, start=391.8274844666652, end=392.10751962499853, duration=0.2800351583333054,
#   45939),
#  (Notes: len=3, start=392.1101697999986, end=392.3902049583319, duration=0.2800351583333054,
#   45940),
#  (Notes: len=2, start=367.65167705833363, end=367.75370405833365, duration=0.10202700000002096,
#   41561),
#  (Notes: len=2, start=368.06271305833366, end=368.1662040583337, duration=0.10349100000001954,
#   41562),
#  (Notes: len=1, start=172.40286892500023, end=172.48388867500023, duration=0.08101974999999584,
#   607),
#  (Notes: len=2, start=782.900339214584, end=783.1732141729174, duration=0.2728749583333183,
#   51667),
#  (Notes: len=1, start=331.69677325000026, end=331.77874050000025, duration=0.08196724999999105,
#   12877),
#  (Notes: len=2, start=331.86070775000024, end=331.94267500000024, duration=0.08196724999999105,
#   12878),
#  (Notes: len=6, start=75.93308848333338, end=76.20390165000003, duration=0.270813166666656,
#   8487),
#  (Notes: len=4, start=442.68133353958405, end=442.80738403958406, duration=0.12605050000001938,
#   5077),
#  (Notes: len=3, start=187.3576276020832, end=187.8091966020832, duration=0.4515690000000063,
#   44677),
#  (Notes: len=51, start=188.03498110208318, end=192.3093896145832, duration=4.274408512500031,
#   44678),
#  (Notes: len=10, start=82.04582911458328, end=84.29693511458328, duration=2.251105999999993,
#   10493),
#  (Notes: len=10, start=84.75477611458328, end=86.95045211458327, duration=2.1956759999999917,
#   10494),
#  (Notes: len=22, start=118.87789541041666, end=121.83814566041664, duration=2.960250249999987,
#   56134),
#  (Notes: len=9, start=121.99488541041664, end=123.24713091041664, duration=1.2522455000000008,
#   56135),
#  (Notes: len=35, start=123.33190541041664, end=126.91107741041665, duration=3.579172000000014,
#   56136),
#  (Notes: len=4, start=128.06850242083334, end=128.78133792083332, duration=0.7128354999999829,
#   20165),
#  (Notes: len=1, start=129.01046792083332, end=129.12503292083332, duration=0.11456499999999892,
#   20166),
#  (Notes: len=1, start=129.46872792083332, end=129.59124692083333, duration=0.12251900000001115,
#   20167),
#  (Notes: len=5, start=129.95390042083332, end=131.4199224208333, duration=1.466021999999981,
#   20168),
#  (Notes: len=2, start=80.2039247083334, end=80.2705491333334, duration=0.06662442500000054,
#   22466),
#  (Notes: len=2, start=80.49940000000001, end=80.857966, duration=0.35856599999999617,
#   56777),
#  (Notes: len=1, start=139.3669125291665, end=139.44372966249986, duration=0.07681713333334983,
#   30899),
#  (Notes: len=14, start=185.45182465625018, end=187.47249965625016, duration=2.020674999999983,
#   43161),
#  (Notes: len=16, start=40.69963704166667, end=43.723225041666666, duration=3.0235879999999966,
#   14628),
#  (Notes: len=9, start=303.30379902916667, end=303.82177282083336, duration=0.5179737916666909,
#   18857),
#  (Notes: len=3, start=303.90510619583335, end=303.98010623333334, duration=0.07500003749998996,
#   18858),
#  (Notes: len=16, start=303.98843957083335, end=305.1698940708333, duration=1.1814544999999725,
#   18859),
#  (Notes: len=3, start=92.83770639375014, end=93.09660894375014, duration=0.25890255000000195,
#   14936),
#  (Notes: len=3, start=93.11023539375014, end=93.37839474375015, duration=0.2681593500000048,
#   14937),
#  (Notes: len=2, start=93.39250839375015, end=93.66066774375014, duration=0.2681593499999906,
#   14938),
#  (Notes: len=16, start=93.67478139375015, end=95.87619991875016, duration=2.2014185250000082,
#   14939),
#  (Notes: len=3, start=95.88996139375016, end=96.14481266875015, duration=0.25485127499999294,
#   14940),
#  (Notes: len=2, start=116.2895752083334, end=116.3379623333334, duration=0.04838712499999076,
#   19100),
#  (Notes: len=4, start=116.41860754166673, end=117.5011233333334, duration=1.0825157916666655,
#   19101),
#  (Notes: len=4, start=117.61065233333339, end=118.03733112500005, duration=0.4266787916666601,
#   19102),
#  (Notes: len=2, start=118.14357854166673, end=118.46727329166673, duration=0.32369475000000136,
#   19103),
#  (Notes: len=7, start=103.6963825520833, end=104.59152742708329, duration=0.8951448749999855,
#   10587),
#  (Notes: len=1, start=104.6776996770833, end=104.7423288645833, duration=0.06462918750000313,
#   10588),
#  (Notes: len=2, start=104.7638719270833, end=104.9362164270833, duration=0.17234449999999413,
#   10589),
#  (Notes: len=1, start=105.0223886770833, end=105.0870178645833, duration=0.06462918750000313,
#   10590),
#  (Notes: len=3, start=18.141595499999998, end=18.579335999999998, duration=0.4377405000000003,
#   24441),
#  (Notes: len=1, start=241.12870964374997, end=241.19205164374998, duration=0.06334200000000578,
#   19670),
#  (Notes: len=6, start=241.25539364374998, end=241.9166491020833, duration=0.6612554583333292,
#   19671),
#  (Notes: len=4, start=242.05035372708332, end=242.69574222708331, duration=0.6453884999999957,
#   19672),
#  (Notes: len=6, start=20.94603349999999, end=21.276589749999992, duration=0.3305562500000008,
#   17893),
#  (Notes: len=6, start=21.399038749999992, end=21.74248699999999, duration=0.343448249999998,
#   17894),
#  (Notes: len=1, start=188.32345363541754, end=188.42043632291754, duration=0.09698268750000238,
#   29327),
#  (Notes: len=1, start=84.26216687499995, end=84.32854137499994, duration=0.0663744999999949,
#   54363),
#  (Notes: len=1, start=84.39491587499994, end=84.46129037499995, duration=0.0663745000000091,
#   54364),
#  (Notes: len=1, start=84.52766487499994, end=84.59403937499995, duration=0.0663745000000091,
#   54365),
#  (Notes: len=1, start=84.66041387499995, end=84.72678837499994, duration=0.0663744999999949,
#   54366),
#  (Notes: len=1, start=84.79316287499995, end=84.85953737499995, duration=0.0663744999999949,
#   54367),
#  (Notes: len=3, start=174.64309137499993, end=174.90862487499993, duration=0.26553350000000364,
#   50712),
#  (Notes: len=4, start=175.46084187499991, end=175.5927864249999, duration=0.13194454999998584,
#   50713),
#  (Notes: len=4, start=175.59973087499992, end=175.7316754249999, duration=0.13194454999998584,
#   50714),
#  (Notes: len=4, start=176.00528637499994, end=176.13195296249992, duration=0.12666658749998305,
#   50715),
#  (Notes: len=21, start=216.90231967291678, end=221.42933089166678, duration=4.527011218750005,
#   26810),
#  (Notes: len=4, start=577.7696811083301, end=578.1072073583301, duration=0.33752624999999625,
#   10342),
#  (Notes: len=3, start=11.81061008333333, end=11.87749683333333, duration=0.0668867500000001,
#   54027),
#  (Notes: len=6, start=175.60316007708326, end=177.0641876041666, duration=1.4610275270833313,
#   31826),
#  (Notes: len=4, start=177.5109153541666, end=179.05687423124996, duration=1.5459588770833648,
#   31827),
#  (Notes: len=15, start=280.31284511250044, end=282.3807460791672, duration=2.067900966666741,
#   36895),
#  (Notes: len=29, start=121.22506723333335, end=123.74567648333334, duration=2.5206092499999926,
#   8568),
#  (Notes: len=4, start=270.3948107937502, end=271.0687506895835, duration=0.673939895833314,
#   5513),
#  (Notes: len=10, start=126.04951745416663, end=127.14918064166662, duration=1.099663187499985,
#   28308),
#  (Notes: len=1, start=83.02751637499993, end=83.31440189583327, duration=0.2868855208333372,
#   47229),
#  (Notes: len=2, start=83.32259862499993, end=83.37098574999993, duration=0.04838712500000497,
#   47230),
#  (Notes: len=4, start=497.31781781041747, end=497.58621472708415, duration=0.2683969166666884,
#   15878),
#  (Notes: len=4, start=497.8575458520842, end=498.1351467270842, duration=0.27760087500001873,
#   15879),
#  (Notes: len=4, start=498.43069651875084, end=498.7794412687508, duration=0.3487447499999803,
#   15880),
#  (Notes: len=1, start=105.97992637083351, end=106.0800946208335, duration=0.10016824999999585,
#   17625),
#  (Notes: len=1, start=106.08093637083351, end=106.18121552708351, duration=0.1002791562499965,
#   17626),
#  (Notes: len=1, start=88.73304488333345, end=88.80621563333345, duration=0.07317075000000273,
#   21595),
#  (Notes: len=1, start=15.750851749999994, end=15.833954249999994, duration=0.08310250000000075,
#   45586),
#  (Notes: len=3, start=35.02219450000001, end=35.305776625000014, duration=0.28358212500000235,
#   57081),
#  (Notes: len=49, start=35.32070200000001, end=44.85881674999999, duration=9.538114749999977,
#   57082),
#  (Notes: len=3, start=45.46062674999999, end=45.74280477499999, duration=0.28217802500000033,
#   57083),
#  (Notes: len=3, start=45.75765624999999, end=46.36882174999999, duration=0.6111654999999985,
#   57084),
#  (Notes: len=3, start=46.66585124999999, end=46.94802927499999, duration=0.28217802500000033,
#   57085),
#  (Notes: len=6, start=499.10026647291676, end=499.64983722291674, duration=0.5495707499999867,
#   11317),
#  (Notes: len=2, start=373.17134087916634, end=373.31153762916637, duration=0.14019675000002962,
#   53246),
#  (Notes: len=4, start=373.3590074624997, end=373.49692571249966, duration=0.13791824999998425,
#   53247),
#  (Notes: len=4, start=373.5428984624997, end=373.6808167124997, duration=0.13791824999998425,
#   53248),
#  (Notes: len=3, start=182.3384505520841, end=182.5948610520841, duration=0.256410499999987,
#   29291),
#  (Notes: len=2, start=162.08873972500007, end=162.76649340000006, duration=0.6777536749999911,
#   39761),
#  (Notes: len=12, start=162.80286585000007, end=169.24323219166664, duration=6.440366341666561,
#   39762),
#  (Notes: len=2, start=169.27481114166662, end=169.89301244166663, duration=0.6182013000000097,
#   39763),
#  (Notes: len=2, start=261.9471039583332, end=262.6250699583332, duration=0.6779660000000263,
#   26465),
#  (Notes: len=4, start=4.0680445, end=4.57904, duration=0.5109954999999999,
#   13072),
#  (Notes: len=4, start=5.188415, end=5.696673625, duration=0.5082586249999999,
#   13073),
#  (Notes: len=1, start=354.3751367166665, end=354.4778220645831, duration=0.10268534791663342,
#   8932),
#  (Notes: len=1, start=354.47868496666644, end=354.5813703145831, duration=0.10268534791669026,
#   8933),
#  (Notes: len=1, start=354.58223321666645, end=354.68491856458314, duration=0.10268534791669026,
#   8934),
#  (Notes: len=7, start=120.27238267708329, end=121.15318217708328, duration=0.8807994999999949,
#   10604),
#  (Notes: len=7, start=121.32446417708329, end=122.20467517708329, duration=0.8802110000000027,
#   10605),
#  (Notes: len=14, start=122.54936417708329, end=124.30448992708328, duration=1.7551257499999906,
#   10606),
#  (Notes: len=16, start=158.77310674583322, end=162.0599329958332, duration=3.28682624999999,
#   7702),
#  (Notes: len=10, start=162.31414849583322, end=165.24885537083327, duration=2.934706875000046,
#   7703),
#  (Notes: len=4, start=153.7227970916669, end=153.9720080916669, duration=0.2492110000000025,
#   18423),
#  (Notes: len=5, start=154.0996568416669, end=154.47300559166692, duration=0.37334875000001944,
#   18424),
#  (Notes: len=2, start=621.8216019374961, end=621.9209396874961, duration=0.09933775000001788,
#   35273),
#  (Notes: len=2, start=622.0202774374961, end=622.1365564374961, duration=0.11627899999996316,
#   35274),
#  (Notes: len=2, start=74.07637792499996, end=74.17840492499997, duration=0.10202700000000675,
#   41265),
#  (Notes: len=2, start=74.28043192499996, end=74.38245892499997, duration=0.10202700000000675,
#   41266),
#  (Notes: len=1, start=294.48541941666673, end=295.08215301041673, duration=0.5967335937500025,
#   49339),
#  (Notes: len=3, start=295.08843441666676, end=295.68218441666676, duration=0.59375,
#   49340),
#  (Notes: len=3, start=46.568557102083325, end=47.10534635208333, duration=0.5367892500000053,
#   23987),
#  (Notes: len=2, start=47.18215910208333, end=47.66078310208333, duration=0.4786239999999964,
#   23988),
#  (Notes: len=3, start=47.81208435208333, end=48.35093835208333, duration=0.5388540000000006,
#   23989),
#  (Notes: len=2, start=48.427751102083334, end=48.90637510208333, duration=0.4786239999999964,
#   23990),
#  (Notes: len=3, start=49.057676352083334, end=49.59764110208333, duration=0.5399647499999958,
#   23991),
#  (Notes: len=2, start=242.50420594583326, end=242.62093744583325, duration=0.116731499999986,
#   5776),
#  (Notes: len=2, start=242.73766894583326, end=242.85440044583325, duration=0.116731499999986,
#   5777),
#  (Notes: len=6, start=279.5039711770832, end=279.8005564833332, duration=0.2965853062499946,
#   36070),
#  (Notes: len=3, start=393.4374062166665, end=393.7611474666665, duration=0.32374125000001186,
#   4451),
#  (Notes: len=1, start=114.57439292083328, end=114.62897017083328, duration=0.05457725000000835,
#   58329),
#  (Notes: len=47, start=87.27115087499999, end=108.94068287499998, duration=21.66953199999999,
#   44793),
#  (Notes: len=87, start=110.50825987499998, end=130.2003837916666, duration=19.69212391666663,
#   44794),
#  (Notes: len=2, start=288.18332250625036, end=288.22793350625034, duration=0.044610999999974865,
#   50112),
#  (Notes: len=2, start=288.3617665062504, end=288.4054677562504, duration=0.04370125000002645,
#   50113),
#  (Notes: len=2, start=288.53657150625037, end=288.5812755062504, duration=0.04470400000002428,
#   50114),
#  (Notes: len=3, start=269.8257014874995, end=270.2243024874995, duration=0.3986009999999851,
#   47664),
#  (Notes: len=3, start=270.2452814874995, end=270.65535373749947, duration=0.4100722499999847,
#   47665),
#  (Notes: len=6, start=75.87732145833338, end=76.23568033333338, duration=0.3583588749999933,
#   21906),
#  (Notes: len=6, start=76.44690845833338, end=76.79940020833338, duration=0.35249174999999866,
#   21907),
#  (Notes: len=1, start=253.4105055541665, end=253.4574833041665, duration=0.04697774999999638,
#   43971),
#  (Notes: len=5, start=253.50446105416648, end=254.2467893041665, duration=0.7423282500000141,
#   43972),
#  (Notes: len=2, start=103.80262399166666, end=103.95714069166667, duration=0.15451670000000206,
#   16332),
#  (Notes: len=2, start=103.96012335833333, end=104.11738764166667, duration=0.1572642833333333,
#   16333),
#  (Notes: len=3, start=179.5551943083334, end=179.69218055833338, duration=0.13698624999997833,
#   13283),
#  (Notes: len=3, start=180.1031393083334, end=180.24012555833338, duration=0.13698624999997833,
#   13284),
#  (Notes: len=3, start=180.37711180833338, end=180.5140980583334, duration=0.13698625000000675,
#   13285),
#  (Notes: len=3, start=648.7842260937493, end=648.9024573437493, duration=0.118231250000008,
#   11417),
#  (Notes: len=3, start=649.0206885937494, end=649.4480707937494, duration=0.4273822000000109,
#   11418),
#  (Notes: len=9, start=649.4705645937494, end=650.4978343437494, duration=1.0272697500000731,
#   11419),
#  (Notes: len=3, start=650.6078290937494, end=650.7324448437494, duration=0.12461574999997538,
#   11420),
#  (Notes: len=3, start=650.8570605937493, end=651.2928779687494, duration=0.435817375000056,
#   11421),
#  (Notes: len=2, start=47.10366764166669, end=47.475584787500026, duration=0.37191714583333635,
#   8259),
#  (Notes: len=10, start=47.96390768333336, end=50.430163600000036, duration=2.4662559166666753,
#   8260),
#  (Notes: len=4, start=0.0, end=0.3588255, duration=0.3588255, 14022),
#  (Notes: len=2, start=209.16546437291768, end=209.2530129979177, duration=0.08754862500001082,
#   29440),
#  (Notes: len=1, start=207.9867981666666, end=208.0431891666666, duration=0.056390999999990754,
#   1214),
#  (Notes: len=3, start=274.30141854166624, end=274.4429280416662, duration=0.14150949999998375,
#   53086),
#  (Notes: len=1, start=264.7625970458331, end=264.8404571708331, duration=0.07786012499997241,
#   38985),
#  (Notes: len=1, start=262.77921741666677, end=262.83436441666674, duration=0.05514699999997674,
#   1453),
#  (Notes: len=1, start=263.00145166666675, end=263.0574217916668, duration=0.05597012500004439,
#   1454),
#  (Notes: len=3, start=299.23361958333373, end=299.58327003333375, duration=0.3496504500000128,
#   48547),
#  (Notes: len=6, start=399.5557779750001, end=401.3211261250001, duration=1.7653481499999657,
#   48747),
#  (Notes: len=1, start=65.41370700000004, end=65.52602450000005, duration=0.11231750000000318,
#   9824),
#  (Notes: len=1, start=65.5634636666667, end=65.6753454166667, duration=0.1118817499999949,
#   9825),
#  (Notes: len=1, start=65.71263933333337, end=65.82452108333338, duration=0.1118817500000091,
#   9826),
#  (Notes: len=1, start=65.86181500000004, end=65.97369675000004, duration=0.1118817500000091,
#   9827),
#  (Notes: len=1, start=66.0109906666667, end=66.12287241666671, duration=0.1118817500000091,
#   9828),
#  (Notes: len=2, start=153.17221482916662, end=154.12724628541662, duration=0.9550314562499977,
#   24359),
#  (Notes: len=15, start=154.25906803541662, end=158.81464178541665, duration=4.555573750000036,
#   24360),
#  (Notes: len=2, start=74.143476125, end=74.67225987500001, duration=0.5287837500000023,
#   23103),
#  (Notes: len=1, start=388.8166205041664, end=389.0166205291664, duration=0.20000002500000846,
#   46827),
#  (Notes: len=1, start=389.0388427541664, end=389.2316999291664, duration=0.1928571749999719,
#   46828),
#  (Notes: len=3, start=648.7911383770818, end=649.2522847520818, duration=0.46114637499999844,
#   55196),
#  (Notes: len=1, start=30.060309124999986, end=30.128491874999984, duration=0.0681827499999983,
#   55880),
#  (Notes: len=1, start=112.36518141666686, end=112.46347285208353, duration=0.09829143541666951,
#   17688),
#  (Notes: len=1, start=112.46430066666686, end=112.56291785208353, duration=0.0986171854166713,
#   17689),
#  (Notes: len=1, start=112.56374841666685, end=112.66269358333352, duration=0.09894516666666675,
#   17690),
#  (Notes: len=1, start=112.66352691666685, end=112.76280229583351, duration=0.09927537916665585,
#   17691),
#  (Notes: len=1, start=112.76363841666685, end=112.86269323958352, duration=0.09905482291667056,
#   17692),
#  (Notes: len=1, start=112.86353216666686, end=112.96531003958353, duration=0.10177787291667073,
#   17693),
#  (Notes: len=17, start=67.13866470833338, end=72.43157295833336, duration=5.292908249999982,
#   21902),
#  (Notes: len=2, start=73.22115095833335, end=73.29531295833335, duration=0.07416200000000117,
#   21903),
#  (Notes: len=2, start=80.15453324999997, end=80.23645124999997, duration=0.08191800000000171,
#   11797),
#  (Notes: len=2, start=80.31836924999998, end=80.40028724999998, duration=0.08191800000000171,
#   11798),
#  (Notes: len=2, start=80.48220524999998, end=80.56202224999998, duration=0.07981700000000558,
#   11799),
#  (Notes: len=2, start=80.64183924999998, end=80.72165624999998, duration=0.07981700000000558,
#   11800),
#  (Notes: len=4, start=71.28703477291675, end=72.04723477291675, duration=0.7601999999999975,
#   23788),
#  (Notes: len=11, start=488.1375823437507, end=490.8166785104174, duration=2.6790961666666817,
#   27041),
#  (Notes: len=6, start=491.312813177084, end=491.799826177084, duration=0.48701299999999037,
#   27042),
#  (Notes: len=6, start=158.59949870833324, end=159.92999985416657, duration=1.330501145833324,
#   39299),
#  (Notes: len=3, start=188.55761349999943, end=188.7906239999994, duration=0.23301049999997758,
#   56935),
#  (Notes: len=4, start=366.6349272166654, end=366.9457113749987, duration=0.31078415833331974,
#   45867),
#  (Notes: len=2, start=366.9486525499987, end=367.29475248958204, duration=0.3460999395833255,
#   45868),
#  (Notes: len=1, start=170.05856499999942, end=170.18294299999943, duration=0.1243780000000072,
#   56912),
#  (Notes: len=7, start=170.30549199999942, end=171.12906599999943, duration=0.8235740000000078,
#   56913),
#  (Notes: len=1, start=171.3570294999994, end=171.4144567499994, duration=0.05742724999998927,
#   56914),
#  (Notes: len=1, start=171.47188399999942, end=171.59473399999942, duration=0.12284999999999968,
#   56915),
#  (Notes: len=7, start=171.71758399999942, end=172.54033499999943, duration=0.8227510000000109,
#   56916),
#  (Notes: len=1, start=172.7674354999994, end=172.82667724999942, duration=0.059241750000012416,
#   56917),
#  (Notes: len=4, start=229.3989866708334, end=231.9704156708334, duration=2.571428999999995,
#   6779),
#  (Notes: len=3, start=232.60732042083342, end=232.79829256666673, duration=0.1909721458333138,
#   6780),
#  (Notes: len=3, start=63.50259642083329, end=63.6139136708333, duration=0.11131725000000614,
#   23243),
#  (Notes: len=3, start=63.728051670833295, end=63.8421896708333, duration=0.11413800000000407,
#   23244),
#  (Notes: len=1, start=63.9610674208333, end=64.0799451708333, duration=0.11887774999999579,
#   23245),
#  (Notes: len=3, start=64.19205267083329, end=64.3041601708333, duration=0.11210750000000758,
#   23246),
#  (Notes: len=3, start=64.41626767083329, end=64.5283751708333, duration=0.11210750000000758,
#   23247),
#  (Notes: len=2, start=70.29813833333337, end=70.41892108333337, duration=0.1207827500000036,
#   14394),
#  (Notes: len=3, start=406.08400767291647, end=406.1703784229165, duration=0.0863707500000146,
#   34884),
#  (Notes: len=1, start=277.77700355416664, end=277.8652388041666, duration=0.08823524999996835,
#   34630),
#  (Notes: len=17, start=0.0, end=2.025429, duration=2.025429, 25893),
#  (Notes: len=23, start=2.3630005, end=6.651025424999999, duration=4.288024924999999,
#   25894),
#  (Notes: len=4, start=6.734118674999999, end=7.320788924999999, duration=0.5866702500000001,
#   25895),
#  (Notes: len=4, start=7.403460924999999, end=7.989805799999998, duration=0.5863448749999991,
#   25896),
#  (Notes: len=1, start=247.8717445541665, end=247.9170480541665, duration=0.04530349999998862,
#   43965),
#  (Notes: len=1, start=248.0529585541665, end=248.1011435541665, duration=0.048184999999989486,
#   43966),
#  (Notes: len=19, start=248.2456985541665, end=251.6613135541665, duration=3.4156150000000025,
#   43967),
#  (Notes: len=1, start=619.148394797919, end=619.388644797919, duration=0.24025000000006003,
#   42761),
#  (Notes: len=4, start=394.7192802895841, end=394.8514387895841, duration=0.13215850000000273,
#   5041),
#  (Notes: len=7, start=20.316057250000004, end=20.737989125000002, duration=0.4219318749999985,
#   37567),
#  (Notes: len=7, start=319.9524881041668, end=321.71446995833344, duration=1.7619818541666632,
#   25339),
#  (Notes: len=2, start=20.668330999999995, end=20.854638987499996, duration=0.1863079875000011,
#   30520),
#  (Notes: len=3, start=145.9184865000001, end=146.0292940000001, duration=0.11080749999999284,
#   58954),
#  (Notes: len=3, start=146.14010150000013, end=146.24790650000014, duration=0.10780500000001325,
#   58955),
#  (Notes: len=2, start=69.06243814999996, end=69.29517752499996, duration=0.2327393749999942,
#   43728),
#  (Notes: len=2, start=69.37358014999997, end=69.61061777499997, duration=0.23703762499999925,
#   43729),
#  (Notes: len=12, start=60.57344704375005, end=62.06688729375006, duration=1.4934402500000061,
#   6956),
#  (Notes: len=4, start=62.21251829375005, end=62.72400304375005, duration=0.511484750000001,
#   6957),
#  (Notes: len=1, start=62.797173793750055, end=62.88191954375006, duration=0.08474575000000328,
#   6958),
#  (Notes: len=1, start=62.966665293750054, end=63.25863629375005, duration=0.29197099999999665,
#   6959),
#  (Notes: len=4, start=63.40462179375005, end=63.91861804375006, duration=0.5139962500000053,
#   6960),
#  (Notes: len=1, start=63.991788793750054, end=64.07750304375006, duration=0.08571425000000232,
#   6961),
#  (Notes: len=1, start=64.16321729375005, end=64.45951329375005, duration=0.2962959999999981,
#   6962),
#  (Notes: len=3, start=610.8709716270819, end=611.3437710645819, duration=0.4727994375000435,
#   55116),
#  (Notes: len=3, start=173.6744308083334, end=173.82006180833338, duration=0.1456309999999803,
#   13268),
#  (Notes: len=3, start=173.9656928083334, end=174.1113238083334, duration=0.14563100000000873,
#   13269),
#  (Notes: len=2, start=340.1690599166669, end=340.24387291666693, duration=0.07481300000000601,
#   12899),
#  (Notes: len=14, start=53.979705333333335, end=56.69505958333335, duration=2.7153542500000114,
#   57191),
#  (Notes: len=3, start=56.95147008333335, end=57.46817283333335, duration=0.5167027500000003,
#   57192),
#  (Notes: len=19, start=57.74854683333335, end=60.852594916666675, duration=3.104048083333325,
#   57193),
#  (Notes: len=16, start=61.218104666666676, end=63.62695029166668, duration=2.408845625000005,
#   57194),
#  (Notes: len=2, start=37.38963724999999, end=37.719106374999996, duration=0.3294691250000028,
#   8103),
#  (Notes: len=1, start=110.64534516666681, end=110.74385510208349, duration=0.09850993541667208,
#   17671),
#  (Notes: len=1, start=110.74468291666682, end=110.84286783333349, duration=0.09818491666666773,
#   17672),
#  (Notes: len=1, start=110.84369291666682, end=110.9422028520835, duration=0.09850993541667208,
#   17673),
#  (Notes: len=1, start=104.6474672499999, end=104.71405699999991, duration=0.06658975000000567,
#   45312),
#  (Notes: len=3, start=104.7806467499999, end=105.10722587499991, duration=0.3265791250000092,
#   45313),
#  (Notes: len=5, start=48.49248490833337, end=48.84793490833337, duration=0.3554500000000047,
#   15504),
#  (Notes: len=1, start=48.91902490833337, end=48.99011490833337, duration=0.0710899999999981,
#   15505),
#  (Notes: len=4, start=24.404815770833338, end=24.54969152083334, duration=0.14487575000000064,
#   32215),
#  (Notes: len=4, start=24.597602583333337, end=24.741335770833338, duration=0.14373318750000053,
#   32216),
#  (Notes: len=4, start=24.789246833333337, end=24.932980020833337, duration=0.14373318750000053,
#   32217),
#  (Notes: len=4, start=24.98089108333334, end=25.13943114583334, duration=0.1585400624999984,
#   32218),
#  (Notes: len=36, start=25.19227783333334, end=26.929687270833337, duration=1.7374094374999984,
#   32219),
#  (Notes: len=3, start=375.37770210416636, end=375.8722074791664, duration=0.494505375000017,
#   5534),
#  (Notes: len=3, start=376.0334978541664, end=376.51736897916635, duration=0.48387112499995055,
#   5535),
#  (Notes: len=11, start=376.67865935416637, end=378.5036903666663, duration=1.8250310124999487,
#   5536),
#  (Notes: len=8, start=378.5100194791663, end=379.807296445833, duration=1.2972769666666863,
#   5537),
#  (Notes: len=2, start=110.78490668541674, end=110.94012855208342, duration=0.15522186666667892,
#   33170),
#  (Notes: len=3, start=111.09577855208342, end=111.26249767708342, duration=0.1667191250000002,
#   33171),
#  (Notes: len=7, start=111.44028592708342, end=112.22866167708342, duration=0.7883757500000002,
#   33172),
#  (Notes: len=2, start=112.38361083333342, end=112.54079267708343, duration=0.15718184375000988,
#   33173),
#  (Notes: len=2, start=112.70016705208343, end=112.95239261458343, duration=0.2522255625000014,
#   33174),
#  (Notes: len=2, start=113.03823448958343, end=113.28938386458343, duration=0.2511493749999971,
#   33175),
#  (Notes: len=3, start=113.37203761458343, end=113.62963886458343, duration=0.25760124999999334,
#   33176),
#  (Notes: len=1, start=371.33676402708284, end=371.3862200270828, duration=0.04945599999996375,
#   44067),
#  (Notes: len=6, start=371.5345880270828, end=372.6605155270828, duration=1.1259274999999889,
#   44068),
#  (Notes: len=1, start=372.8466775270828, end=372.89250702708284, duration=0.045829500000024836,
#   44069),
#  (Notes: len=29, start=17.407711887499996, end=22.4610288875, duration=5.053317000000003,
#   26094),
#  (Notes: len=9, start=23.0165843875, end=25.3936323875, duration=2.3770479999999985,
#   26095),
#  (Notes: len=5, start=25.736489387499997, end=26.72196222083333, duration=0.9854728333333327,
#   26096),
#  (Notes: len=5, start=27.06094522083333, end=28.041465554166663, duration=0.9805203333333345,
#   26097),
#  (Notes: len=13, start=61.692111433333324, end=67.51728825208333, duration=5.825176818750009,
#   33134),
#  (Notes: len=1, start=71.79317415624992, end=71.86111309374992, duration=0.0679389375000028,
#   30099),
#  (Notes: len=2, start=71.88375940624992, end=71.95169834374992, duration=0.0679389375000028,
#   30100),
#  (Notes: len=1, start=85.95332949999998, end=86.02733233333332, duration=0.07400283333333846,
#   58842),
#  (Notes: len=1, start=86.10133516666666, end=86.17533799999998, duration=0.07400283333332425,
#   58843),
#  (Notes: len=1, start=86.24934083333332, end=86.32334366666666, duration=0.07400283333333846,
#   58844),
#  (Notes: len=2, start=293.5283049312503, end=293.63010135625035, duration=0.10179642500003183,
#   32076),
#  (Notes: len=1, start=293.6480654312503, end=293.82770618125033, duration=0.17964075000003277,
#   32077),
#  (Notes: len=14, start=294.0073469312503, end=295.07509018125035, duration=1.067743250000035,
#   32078),
#  (Notes: len=4, start=496.8645948687507, end=497.1551518687507, duration=0.2905569999999784,
#   19970),
#  (Notes: len=4, start=497.3004303687507, end=497.5909873687507, duration=0.2905569999999784,
#   19971),
#  (Notes: len=1, start=110.69855672083337, end=110.78584040833337, duration=0.0872836875000047,
#   2780),
#  (Notes: len=2, start=110.81493497083336, end=110.90802553333336, duration=0.09309056249999514,
#   2781),
#  (Notes: len=1, start=110.93905572083337, end=111.02633940833337, duration=0.0872836875000047,
#   2782),
#  (Notes: len=2, start=111.05543397083336, end=111.14271765833337, duration=0.0872836875000047,
#   2783),
#  (Notes: len=3, start=97.22811834166666, end=97.46787448124999, duration=0.23975613958333497,
#   16297),
#  (Notes: len=4, start=97.47185125625, end=97.7850222875, duration=0.31317103124999335,
#   16298),
#  (Notes: len=1, start=97.78799014583333, end=97.86634781250001, duration=0.0783576666666761,
#   16299),
#  (Notes: len=4, start=502.25766547291676, end=502.3712072229168, duration=0.11354175000002442,
#   11324),
#  (Notes: len=2, start=784.0544051312507, end=784.3252312645841, duration=0.27082613333334393,
#   51671),
#  (Notes: len=3, start=78.58070218541667, end=79.15981347083333, duration=0.5791112854166585,
#   2277),
#  (Notes: len=3, start=79.17942132083333, end=79.76766757083332, duration=0.5882462499999974,
#   2278),
#  (Notes: len=2, start=7.6894319, end=7.7979154, duration=0.10848350000000018,
#   20190),
#  (Notes: len=2, start=8.124946399999999, end=8.343493899999999, duration=0.21854749999999967,
#   20191),
#  (Notes: len=2, start=8.5620414, end=8.7805889, duration=0.21854749999999967,
#   20192),
#  (Notes: len=2, start=8.9991364, end=9.11384165, duration=0.11470525000000009,
#   20193),
#  (Notes: len=3, start=141.22271799375014, end=142.88082799375013, duration=1.6581099999999935,
#   11011),
#  (Notes: len=34, start=143.43756899375012, end=153.3928454937501, duration=9.955276499999968,
#   11012),
#  (Notes: len=13, start=111.35652620000018, end=114.95906620000017, duration=3.6025399999999905,
#   18920),
#  (Notes: len=14, start=115.31006670000016, end=121.1667601166668, duration=5.85669341666663,
#   18921),
#  (Notes: len=31, start=121.87866203333346, end=136.30155313333344, duration=14.422891099999987,
#   18922),
#  (Notes: len=2, start=329.57667316666647, end=330.32929066666645, duration=0.7526174999999853,
#   36107),
#  (Notes: len=12, start=330.4770739166664, end=331.9199420416665, duration=1.442868125000075,
#   36108),
#  (Notes: len=3, start=496.8468220958335, end=496.9455063458335, duration=0.09868425000001935,
#   36420),
#  (Notes: len=2, start=161.8406611958333, end=161.9640405208333, duration=0.12337932500000193,
#   31043),
#  (Notes: len=4, start=98.76387608749998, end=98.98341508749998, duration=0.2195389999999975,
#   23343),
#  (Notes: len=10, start=99.09318458749998, end=99.76050983749998, duration=0.6673252500000046,
#   23344),
#  (Notes: len=3, start=99.87065808749999, end=99.98080633749998, duration=0.11014824999999462,
#   23345),
#  (Notes: len=4, start=250.24193412083343, end=250.33852137083343, duration=0.0965872499999989,
#   50478),
#  (Notes: len=4, start=250.43510862083343, end=250.82702320416678, duration=0.39191458333334594,
#   50479),
#  (Notes: len=2, start=65.12767462083337, end=66.43992208541667, duration=1.3122474645832938,
#   6497),
#  (Notes: len=1, start=67.09745608541667, end=67.17964783541667, duration=0.08219175000000689,
#   6498),
#  (Notes: len=2, start=88.92701436249988, end=89.04896561249988, duration=0.12195125000000928,
#   28213),
#  (Notes: len=2, start=89.12530152916655, end=89.20077432083322, duration=0.07547279166666954,
#   28214),
#  (Notes: len=8, start=152.50760648333355, end=155.67506248333356, duration=3.1674560000000156,
#   58146),
#  (Notes: len=8, start=158.74565135833353, end=161.91310735833355, duration=3.1674560000000156,
#   58147),
#  (Notes: len=322, start=0.0, end=67.62875079166675, duration=67.62875079166675,
#   58148),
#  (Notes: len=1, start=109.03773300000009, end=109.10430200000009, duration=0.06656900000000121,
#   19368),
#  (Notes: len=2, start=143.61366963333325, end=143.77584600833325, duration=0.16217637500000137,
#   20398),
#  (Notes: len=2, start=144.04903038333325, end=145.39480125833325, duration=1.3457708749999995,
#   20399),
#  (Notes: len=16, start=75.07051191666666, end=113.19529591666668, duration=38.12478400000002,
#   8315),
#  (Notes: len=13, start=117.23563358333335, end=139.8280580833333, duration=22.59242449999995,
#   8316),
#  (Notes: len=11, start=213.55929779166695, end=231.78073593750034, duration=18.22143814583339,
#   8317),
#  (Notes: len=2, start=167.05070728125034, end=167.16408023958368, duration=0.11337295833334338,
#   7356),
#  (Notes: len=1, start=141.3452905208334, end=141.68673712916672, duration=0.34144660833331386,
#   14635),
#  (Notes: len=4, start=601.9493318687477, end=602.0841144437477, duration=0.1347825750000311,
#   35224),
#  (Notes: len=3, start=9.934260283333336, end=10.004353783333336, duration=0.07009350000000047,
#   32438),
#  (Notes: len=3, start=10.121176283333336, end=10.193523533333336, duration=0.07234724999999997,
#   32439),
#  (Notes: len=4, start=366.0107622541677, end=366.4082885041677, duration=0.3975262499999985,
#   53662),
#  (Notes: len=5, start=30.315681500000036, end=30.570755250000033, duration=0.25507374999999755,
#   23732),
#  (Notes: len=5, start=30.657450500000035, end=30.912524250000033, duration=0.25507374999999755,
#   23733),
#  (Notes: len=1, start=134.67063705000012, end=134.80050730000013, duration=0.1298702500000104,
#   48343),
#  (Notes: len=3, start=63.54926381458335, end=63.975642564583346, duration=0.4263787499999978,
#   39884),
#  (Notes: len=4, start=466.7473262604173, end=467.0008920104173, duration=0.25356575000000703,
#   52779),
#  (Notes: len=1, start=221.70904374375036, end=221.83113572291703, duration=0.12209197916666881,
#   21443),
#  (Notes: len=2, start=64.4592681666666, end=64.5345190416666, duration=0.07525087499999472,
#   13732),
#  (Notes: len=2, start=64.65993716666661, end=64.7351880416666, duration=0.07525087499999472,
#   13733),
#  (Notes: len=2, start=64.8606061666666, end=64.9346681041666, duration=0.07406193750000511,
#   13734),
#  (Notes: len=1, start=2.9850730000000003, end=3.2066385000000004, duration=0.22156550000000008,
#   26225),
#  (Notes: len=20, start=3.428204, end=6.049426447916665, duration=2.621222447916665,
#   26226),
#  (Notes: len=32, start=6.473754447916665, end=12.775686733333336, duration=6.301932285416671,
#   26227),
#  (Notes: len=10, start=12.784558275000004, end=14.457286587500002, duration=1.6727283124999985,
#   26228),
#  (Notes: len=25, start=14.466139275000003, end=17.90512510208332, duration=3.438985827083318,
#   26229),
#  (Notes: len=1, start=49.018714816666666, end=49.189830316666665, duration=0.1711154999999991,
#   6475),
#  (Notes: len=1, start=53.353207191666655, end=53.499548691666654, duration=0.14634149999999835,
#   26177),
#  (Notes: len=1, start=234.19518528750027, end=234.25298878750024, duration=0.05780349999997725,
#   7789),
#  (Notes: len=1, start=234.31079228750025, end=234.36859578750025, duration=0.05780350000000567,
#   7790),
#  (Notes: len=2, start=244.19315022916678, end=244.28843432083343, duration=0.09528409166665597,
#   36798),
#  (Notes: len=1, start=290.89698145000017, end=291.0072754500002, duration=0.11029400000001033,
#   4347),
#  (Notes: len=3, start=127.50122651458337, end=127.82573801458337, duration=0.32451149999999984,
#   20097),
#  (Notes: len=3, start=127.93589451458337, end=128.26636401458336, duration=0.3304694999999924,
#   20098),
#  (Notes: len=8, start=25.36544216666668, end=26.12474466666668, duration=0.7593025000000004,
#   57255),
#  (Notes: len=2, start=499.12231101666515, end=499.21700801666515, duration=0.09469699999999648,
#   10266),
#  (Notes: len=10, start=344.3465271270834, end=345.46982675208335, duration=1.1232996249999587,
#   40141),
#  (Notes: len=7, start=52.2890363333334, end=53.8022643333334, duration=1.513227999999998,
#   57520),
#  (Notes: len=3, start=75.75147948333337, end=75.84228398333337, duration=0.0908045000000044,
#   8486),
#  (Notes: len=6, start=75.93308848333338, end=76.20390165000003, duration=0.270813166666656,
#   8487),
#  (Notes: len=15, start=59.144842245833395, end=62.017662287500066, duration=2.872820041666671,
#   15660),
#  (Notes: len=22, start=62.4142023708334, end=66.50637062083341, duration=4.092168250000007,
#   15661),
#  (Notes: len=10, start=68.36934303750006, end=69.69923150416672, duration=1.3298884666666595,
#   15662),
#  (Notes: len=1, start=227.25727105416658, end=227.30672705416657, duration=0.04945599999999217,
#   43950),
#  (Notes: len=1, start=227.45509505416658, end=227.50455105416657, duration=0.04945599999999217,
#   43951),
#  (Notes: len=19, start=227.65291905416657, end=231.4039490541666, duration=3.7510300000000143,
#   43952),
#  (Notes: len=1, start=17.231558583333317, end=17.328992493749983, duration=0.09743391041666527,
#   16827),
#  (Notes: len=4, start=77.52371105416671, end=78.25000587708338, duration=0.726294822916671,
#   6183),
#  (Notes: len=2, start=305.01359802083306, end=305.8097240208331, duration=0.7961260000000152,
#   42061),
#  (Notes: len=4, start=30.43319325, end=30.94881825, duration=0.515625, 13091),
#  (Notes: len=1, start=36.60843625000003, end=36.72987400000004, duration=0.12143775000000545,
#   20567),
#  (Notes: len=2, start=244.37130091250066, end=244.81111528750066, duration=0.4398143749999974,
#   55570),
#  (Notes: len=2, start=244.81574491250066, end=245.03611506250067, duration=0.22037015000000792,
#   55571),
#  (Notes: len=2, start=185.35273734166694, end=185.43954284166693, duration=0.08680549999999698,
#   31465),
#  (Notes: len=1, start=26.330106500000003, end=26.456157000000005, duration=0.12605050000000162,
#   166),
#  (Notes: len=4, start=405.9989080604166, end=406.4368640604166, duration=0.4379559999999856,
#   11213),
#  (Notes: len=4, start=406.8814060604166, end=407.3193620604166, duration=0.4379559999999856,
#   11214),
#  (Notes: len=4, start=407.7673475604166, end=408.21344456041663, duration=0.44609700000000885,
#   11215),
#  (Notes: len=4, start=408.67842856041665, end=409.13297356041664, duration=0.454544999999996,
#   11216),
#  (Notes: len=31, start=19.3746895, end=25.132729374999993, duration=5.758039874999994,
#   53923),
#  (Notes: len=3, start=166.34757200000016, end=166.90569606875016, duration=0.5581240687500042,
#   22659),
#  (Notes: len=3, start=166.91097800000014, end=167.45134412500013, duration=0.5403661249999914,
#   22660),
#  (Notes: len=25, start=65.83394050000005, end=70.47362400000004, duration=4.63968349999999,
#   26075),
#  (Notes: len=2, start=170.1589323583333, end=170.37810014999997, duration=0.21916779166667766,
#   46547),
#  (Notes: len=2, start=170.38181485833329, end=170.60098264999996, duration=0.21916779166667766,
#   46548),
#  (Notes: len=4, start=40.97035858333336, end=41.03854045833336, duration=0.0681818750000005,
#   922),
#  (Notes: len=2, start=41.21742333333336, end=41.27277383333336, duration=0.05535050000000297,
#   923),
#  (Notes: len=3, start=828.0481476312509, end=828.349066306251, duration=0.3009186750000481,
#   51761),
#  (Notes: len=1, start=282.4061627875, end=282.47897828750007, duration=0.072815500000047,
#   34650),
#  (Notes: len=3, start=838.319728881251, end=838.615894231251, duration=0.29616535000002386,
#   51794),
#  (Notes: len=3, start=838.6314818812509, end=838.927647231251, duration=0.29616535000002386,
#   51795),
#  (Notes: len=33, start=218.2245116666668, end=224.57124350000015, duration=6.346731833333337,
#   51325),
#  (Notes: len=4, start=58.764539583333345, end=59.09634008333335, duration=0.33180050000000705,
#   25978),
#  (Notes: len=12, start=59.296852833333354, end=62.04474283333336, duration=2.7478900000000053,
#   25979),
#  (Notes: len=6, start=67.87948999999998, end=68.57152774999997, duration=0.6920377499999972,
#   12487),
#  (Notes: len=1, start=38.83400908333333, end=38.92575208333333, duration=0.09174300000000102,
#   42953),
#  (Notes: len=1, start=39.01721558333333, end=39.108401083333334, duration=0.0911855000000017,
#   42954),
#  (Notes: len=4, start=502.7285702416655, end=503.2211297416655, duration=0.4925594999999703,
#   46366),
#  (Notes: len=2, start=168.1704020833332, end=168.24791391666653, duration=0.07751183333334666,
#   45536),
#  (Notes: len=1, start=103.52720912083335, end=103.62605624583334, duration=0.09884712499999182,
#   43054),
#  (Notes: len=1, start=103.72539437083334, end=103.82522824583334, duration=0.09983387500000163,
#   43055),
#  (Notes: len=1, start=103.92556312083335, end=104.02640374583335, duration=0.10084062500000357,
#   43056),
#  (Notes: len=4, start=104.12781270416669, end=104.62719445416668, duration=0.49938174999999774,
#   43057),
#  (Notes: len=1, start=104.72396870416668, end=104.82074295416668, duration=0.09677424999999573,
#   43058),
#  (Notes: len=1, start=149.32864076874998, end=149.38261701874998, duration=0.053976250000005166,
#   58441),
#  (Notes: len=98, start=0.25, end=8.72234725, duration=8.47234725, 6109),
#  (Notes: len=3, start=254.1772623583333, end=254.43427162916666, duration=0.25700927083335046,
#   46689),
#  (Notes: len=3, start=254.4576361083333, end=255.20087952499998, duration=0.7432434166666724,
#   46690),
#  (Notes: len=1, start=226.89063505416658, end=226.93646455416658, duration=0.045829499999996415,
#   43948),
#  (Notes: len=11, start=8.21988951875, end=10.44531661875, duration=2.225427100000001,
#   14831),
#  (Notes: len=3, start=10.45844801875, end=10.70794461875, duration=0.2494966000000005,
#   14832),
#  (Notes: len=4, start=36.09312500000001, end=36.35557032500001, duration=0.2624453250000016,
#   5271),
#  (Notes: len=3, start=950.225496704163, end=950.2990262041629, duration=0.07352949999994962,
#   27861),
#  (Notes: len=3, start=950.372555704163, end=950.446085204163, duration=0.07352949999994962,
#   27862),
#  (Notes: len=1, start=133.42622317083325, end=133.51199029583327, duration=0.08576712500001804,
#   39936)]

# %%
for artist, chain in complete_chains.items():
    offset = 0
    # Create a PrettyMIDI object
    chord = pretty_midi.PrettyMIDI()
    program = pretty_midi.instrument_name_to_program('Orchestral Harp')
    instrument = pretty_midi.Instrument(program=program)

    for notes_, _ in chain:
        for new_note in notes_.notes:
            note = pretty_midi.Note(
                velocity=new_note.velocity, pitch=new_note.pitch, start=offset+new_note.start, end=offset+new_note.end)
            instrument.notes.append(note)

        offset += notes_.duration + 0.1

    chord.instruments.append(instrument)
    # Write out the MIDI data
    chord.write(f"test_{artist}_harp.mid")
